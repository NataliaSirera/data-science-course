# %% [markdown]
# # Web scraping

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# # Exercici 1

# %% [markdown]
# Realitza web scraping d'una pàgina de la borsa de Madrid (https://www.bolsamadrid.es) utilitzant BeautifulSoup i Selenium.

# %% [markdown]
# Buscarem els valors de les accions de les diferents companyies del IBEX35 amb BeautifulSoup i Selenium

# %% [markdown]
# ## BeautifulSoup

# %%
# Bolsa madrid link
url = 'https://www.bolsamadrid.es'

# %%
# Download the HTML
html = requests.get(url)

# %%
# Parse the HTML
soup = BeautifulSoup(html.content, 'html.parser')

# %%
# Get the Acciones links
links = [link.get('href') for link in soup.find_all('a', string='Acciones')]

# %%
# Accciones link
url_acciones = url + links[0]

# %%
# Download the HTML
html_acciones = requests.get(url_acciones)

# %%
# Parse the HTML
soup_acciones = BeautifulSoup(html_acciones.content, 'html.parser')

# %%
# Get the table of Acciones
table_acciones = soup_acciones.find(id='ctl00_Contenido_tblAcciones')

# %%
# Check table code
print(table_acciones.prettify())
# Out:
# <table cellpadding="3" cellspacing="0" class="TblPort" id="ctl00_Contenido_tblAcciones" width="100%">
#  <tr align="center">
#   <th scope="col">
#    Nombre
#   </th>
#   <th scope="col">
#    Últ.
#   </th>
#   <th scope="col">
#    % Dif.
#   </th>
#   <th scope="col">
#    Máx.
#   </th>
#   <th scope="col">
#    Mín.
#   </th>
#   <th scope="col">
#    Volumen
#   </th>
#   <th scope="col">
#    Efectivo (miles €)
#   </th>
#   <th scope="col">
#    Fecha
#   </th>
#   <th class="Ult" scope="col">
#    Hora
#   </th>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0125220311">
#     ACCIONA
#    </a>
#   </td>
#   <td>
#    183,3000
#   </td>
#   <td class="DifClSb">
#    0,71
#   </td>
#   <td>
#    183,8000
#   </td>
#   <td>
#    181,1000
#   </td>
#   <td>
#    38.549
#   </td>
#   <td>
#    7.033,22
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:12
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105563003">
#     ACCIONA ENER
#    </a>
#   </td>
#   <td>
#    37,4400
#   </td>
#   <td class="DifClSb">
#    0,32
#   </td>
#   <td>
#    37,6200
#   </td>
#   <td>
#    37,0600
#   </td>
#   <td>
#    95.664
#   </td>
#   <td>
#    3.566,64
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:02
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0132105018">
#     ACERINOX
#    </a>
#   </td>
#   <td>
#    9,3520
#   </td>
#   <td class="DifClBj">
#    -1,18
#   </td>
#   <td>
#    9,4080
#   </td>
#   <td>
#    9,2860
#   </td>
#   <td>
#    230.505
#   </td>
#   <td>
#    2.154,53
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:14
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0167050915">
#     ACS
#    </a>
#   </td>
#   <td>
#    27,2500
#   </td>
#   <td class="DifClSb">
#    0,07
#   </td>
#   <td>
#    27,2900
#   </td>
#   <td>
#    27,0500
#   </td>
#   <td>
#    173.451
#   </td>
#   <td>
#    4.709,06
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:43
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105046009">
#     AENA
#    </a>
#   </td>
#   <td>
#    124,8000
#   </td>
#   <td class="DifClBj">
#    -1,15
#   </td>
#   <td>
#    128,0500
#   </td>
#   <td>
#    124,4500
#   </td>
#   <td>
#    97.824
#   </td>
#   <td>
#    12.317,46
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:20
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0109067019">
#     AMADEUS
#    </a>
#   </td>
#   <td>
#    50,4200
#   </td>
#   <td class="DifClBj">
#    -0,12
#   </td>
#   <td>
#    50,8200
#   </td>
#   <td>
#    50,1600
#   </td>
#   <td>
#    221.081
#   </td>
#   <td>
#    11.164,26
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:23
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=LU1598757687">
#     ARCELORMIT.
#    </a>
#   </td>
#   <td>
#    25,3100
#   </td>
#   <td class="DifClBj">
#    -1,52
#   </td>
#   <td>
#    25,5000
#   </td>
#   <td>
#    25,0050
#   </td>
#   <td>
#    309.135
#   </td>
#   <td>
#    7.805,20
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:43
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113900J37">
#     B.SANTANDER
#    </a>
#   </td>
#   <td>
#    2,8080
#   </td>
#   <td class="DifClBj">
#    -0,12
#   </td>
#   <td>
#    2,8320
#   </td>
#   <td>
#    2,7825
#   </td>
#   <td>
#    17.025.287
#   </td>
#   <td>
#    47.702,77
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:41
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113860A34">
#     BA.SABADELL
#    </a>
#   </td>
#   <td>
#    0,8630
#   </td>
#   <td class="DifClSb">
#    0,33
#   </td>
#   <td>
#    0,8736
#   </td>
#   <td>
#    0,8572
#   </td>
#   <td>
#    8.735.729
#   </td>
#   <td>
#    7.567,01
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:19
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113679I37">
#     BANKINTER
#    </a>
#   </td>
#   <td>
#    5,9800
#   </td>
#   <td class="DifClBj">
#    -0,17
#   </td>
#   <td>
#    6,0420
#   </td>
#   <td>
#    5,9080
#   </td>
#   <td>
#    1.265.246
#   </td>
#   <td>
#    7.544,66
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:24
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113211835">
#     BBVA
#    </a>
#   </td>
#   <td>
#    5,5310
#   </td>
#   <td class="DifClBj">
#    -0,22
#   </td>
#   <td>
#    5,5550
#   </td>
#   <td>
#    5,4880
#   </td>
#   <td>
#    3.938.230
#   </td>
#   <td>
#    21.757,72
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:36
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0140609019">
#     CAIXABANK
#    </a>
#   </td>
#   <td>
#    3,3620
#   </td>
#   <td class="DifClBj">
#    -0,71
#   </td>
#   <td>
#    3,3980
#   </td>
#   <td>
#    3,3400
#   </td>
#   <td>
#    5.420.042
#   </td>
#   <td>
#    18.222,38
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:19:51
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105066007">
#     CELLNEX
#    </a>
#   </td>
#   <td>
#    33,1700
#   </td>
#   <td class="DifClBj">
#    -0,60
#   </td>
#   <td>
#    33,4500
#   </td>
#   <td>
#    33,0500
#   </td>
#   <td>
#    321.537
#   </td>
#   <td>
#    10.688,52
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:22
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0130960018">
#     ENAGAS
#    </a>
#   </td>
#   <td>
#    17,1900
#   </td>
#   <td class="DifClSb">
#    0,38
#   </td>
#   <td>
#    17,2550
#   </td>
#   <td>
#    16,9900
#   </td>
#   <td>
#    601.990
#   </td>
#   <td>
#    10.293,61
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:01
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0130670112">
#     ENDESA
#    </a>
#   </td>
#   <td>
#    17,9650
#   </td>
#   <td class="DifClSb">
#    0,08
#   </td>
#   <td>
#    18,0950
#   </td>
#   <td>
#    17,8850
#   </td>
#   <td>
#    409.778
#   </td>
#   <td>
#    7.356,01
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:23
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0118900010">
#     FERROVIAL
#    </a>
#   </td>
#   <td>
#    25,5800
#   </td>
#   <td class="DifClBj">
#    -0,12
#   </td>
#   <td>
#    25,6400
#   </td>
#   <td>
#    25,4500
#   </td>
#   <td>
#    258.175
#   </td>
#   <td>
#    6.589,95
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:26
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0137650018">
#     FLUIDRA
#    </a>
#   </td>
#   <td>
#    13,7500
#   </td>
#   <td class="DifClSb">
#    0,73
#   </td>
#   <td>
#    13,8300
#   </td>
#   <td>
#    13,5700
#   </td>
#   <td>
#    425.660
#   </td>
#   <td>
#    5.825,79
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:48
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0171996087">
#     GRIFOLS CL.A
#    </a>
#   </td>
#   <td>
#    10,2900
#   </td>
#   <td class="DifClBj">
#    -1,44
#   </td>
#   <td>
#    10,6000
#   </td>
#   <td>
#    10,2650
#   </td>
#   <td>
#    1.120.966
#   </td>
#   <td>
#    11.657,25
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:53
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0177542018">
#     IAG
#    </a>
#   </td>
#   <td>
#    1,5405
#   </td>
#   <td class="DifClBj">
#    -1,15
#   </td>
#   <td>
#    1,5775
#   </td>
#   <td>
#    1,5360
#   </td>
#   <td>
#    7.851.493
#   </td>
#   <td>
#    12.249,88
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:51
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0144580Y14">
#     IBERDROLA
#    </a>
#   </td>
#   <td>
#    10,9400
#   </td>
#   <td class="DifClSb">
#    0,32
#   </td>
#   <td>
#    10,9750
#   </td>
#   <td>
#    10,8600
#   </td>
#   <td>
#    3.029.936
#   </td>
#   <td>
#    33.086,24
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:19:57
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0148396007">
#     INDITEX
#    </a>
#   </td>
#   <td>
#    24,8700
#   </td>
#   <td class="DifClSb">
#    0,40
#   </td>
#   <td>
#    25,0200
#   </td>
#   <td>
#    24,7200
#   </td>
#   <td>
#    891.591
#   </td>
#   <td>
#    22.173,66
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:32
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0118594417">
#     INDRA A
#    </a>
#   </td>
#   <td>
#    10,3300
#   </td>
#   <td class="DifClSb">
#    0,39
#   </td>
#   <td>
#    10,3600
#   </td>
#   <td>
#    10,2000
#   </td>
#   <td>
#    415.544
#   </td>
#   <td>
#    4.279,50
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:16
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0139140174">
#     INM.COLONIAL
#    </a>
#   </td>
#   <td>
#    5,9850
#   </td>
#   <td class="DifClBj">
#    -1,24
#   </td>
#   <td>
#    6,0250
#   </td>
#   <td>
#    5,9350
#   </td>
#   <td>
#    900.897
#   </td>
#   <td>
#    5.393,76
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:41
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0124244E34">
#     MAPFRE
#    </a>
#   </td>
#   <td>
#    1,8000
#   </td>
#   <td class="DifClBj">
#    -0,28
#   </td>
#   <td>
#    1,8180
#   </td>
#   <td>
#    1,7880
#   </td>
#   <td>
#    2.333.488
#   </td>
#   <td>
#    4.193,39
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:43
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0176252718">
#     MELIA HOTELS
#    </a>
#   </td>
#   <td>
#    5,0400
#   </td>
#   <td class="DifClBj">
#    -0,49
#   </td>
#   <td>
#    5,1200
#   </td>
#   <td>
#    5,0400
#   </td>
#   <td>
#    524.955
#   </td>
#   <td>
#    2.665,34
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:42
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105025003">
#     MERLIN
#    </a>
#   </td>
#   <td>
#    9,0650
#   </td>
#   <td class="DifClSb">
#    0,28
#   </td>
#   <td>
#    9,0850
#   </td>
#   <td>
#    8,9950
#   </td>
#   <td>
#    166.475
#   </td>
#   <td>
#    1.505,06
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:13
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0116870314">
#     NATURGY
#    </a>
#   </td>
#   <td>
#    26,7000
#   </td>
#   <td class="DifClSb">
#    0,15
#   </td>
#   <td>
#    26,7700
#   </td>
#   <td>
#    26,5600
#   </td>
#   <td>
#    53.997
#   </td>
#   <td>
#    1.439,95
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:28
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0169501022">
#     PHARMA MAR
#    </a>
#   </td>
#   <td>
#    69,8800
#   </td>
#   <td class="DifClSb">
#    0,87
#   </td>
#   <td>
#    70,2600
#   </td>
#   <td>
#    68,8200
#   </td>
#   <td>
#    49.175
#   </td>
#   <td>
#    3.428,69
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:21
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0173093024">
#     R.E.C.
#    </a>
#   </td>
#   <td>
#    17,2500
#   </td>
#   <td class="DifClSb">
#    0,70
#   </td>
#   <td>
#    17,2950
#   </td>
#   <td>
#    17,1000
#   </td>
#   <td>
#    224.599
#   </td>
#   <td>
#    3.868,30
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:55
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0173516115">
#     REPSOL
#    </a>
#   </td>
#   <td>
#    14,1800
#   </td>
#   <td class="DifClBj">
#    -2,34
#   </td>
#   <td>
#    14,3800
#   </td>
#   <td>
#    14,1400
#   </td>
#   <td>
#    3.569.426
#   </td>
#   <td>
#    50.884,59
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:49
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0157261019">
#     ROVI
#    </a>
#   </td>
#   <td>
#    36,5000
#   </td>
#   <td class="DifClSb">
#    0,44
#   </td>
#   <td>
#    36,6600
#   </td>
#   <td>
#    36,2000
#   </td>
#   <td>
#    77.086
#   </td>
#   <td>
#    2.809,30
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:19:55
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0182870214">
#     SACYR
#    </a>
#   </td>
#   <td>
#    2,6300
#   </td>
#   <td class="DifClBj">
#    -0,60
#   </td>
#   <td>
#    2,6800
#   </td>
#   <td>
#    2,6200
#   </td>
#   <td>
#    1.665.962
#   </td>
#   <td>
#    4.413,62
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:07
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlSb">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0143416115">
#     SIEMENS GAME
#    </a>
#   </td>
#   <td>
#    18,0250
#   </td>
#   <td class="DifClSb">
#    0,06
#   </td>
#   <td>
#    18,0300
#   </td>
#   <td>
#    18,0200
#   </td>
#   <td>
#    563.832
#   </td>
#   <td>
#    10.161,50
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:02
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0165386014">
#     SOLARIA
#    </a>
#   </td>
#   <td>
#    16,9450
#   </td>
#   <td class="DifClBj">
#    -0,09
#   </td>
#   <td>
#    17,0850
#   </td>
#   <td>
#    16,7850
#   </td>
#   <td>
#    151.064
#   </td>
#   <td>
#    2.559,09
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:55
#   </td>
#  </tr>
#  <tr align="right">
#   <td align="left" class="DifFlBj">
#    <a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0178430E18">
#     TELEFONICA
#    </a>
#   </td>
#   <td>
#    3,5230
#   </td>
#   <td class="DifClBj">
#    -1,51
#   </td>
#   <td>
#    3,5780
#   </td>
#   <td>
#    3,5150
#   </td>
#   <td>
#    34.225.447
#   </td>
#   <td>
#    121.073,13
#   </td>
#   <td align="center">
#    07/12/2022
#   </td>
#   <td align="center" class="Ult">
#    17:20:42
#   </td>
#  </tr>
# </table>

# %%
# Parse columns and row values
values = []
for row in table_acciones.find_all('tr'):
    if row.find_all('th'):
        columns = [element.get_text() for element in row.find_all('th')]
    elif row.find_all('td'):
        values.append([element.get_text() for element in row.find_all('td')])

# %%
# Save values into a dataframe
acciones = pd.DataFrame(values, columns=columns)

# %%
# View the dataframe
acciones
# Out:
#           Nombre      Últ. % Dif.      Máx.      Mín.     Volumen  \
# 0        ACCIONA  183,3000   0,71  183,8000  181,1000      38.549
# 1   ACCIONA ENER   37,4400   0,32   37,6200   37,0600      95.664
# 2       ACERINOX    9,3520  -1,18    9,4080    9,2860     230.505
# 3            ACS   27,2500   0,07   27,2900   27,0500     173.451
# 4           AENA  124,8000  -1,15  128,0500  124,4500      97.824
# 5        AMADEUS   50,4200  -0,12   50,8200   50,1600     221.081
# 6    ARCELORMIT.   25,3100  -1,52   25,5000   25,0050     309.135
# 7    B.SANTANDER    2,8080  -0,12    2,8320    2,7825  17.025.287
# 8    BA.SABADELL    0,8630   0,33    0,8736    0,8572   8.735.729
# 9      BANKINTER    5,9800  -0,17    6,0420    5,9080   1.265.246
# 10          BBVA    5,5310  -0,22    5,5550    5,4880   3.938.230
# 11     CAIXABANK    3,3620  -0,71    3,3980    3,3400   5.420.042
# 12       CELLNEX   33,1700  -0,60   33,4500   33,0500     321.537
# 13        ENAGAS   17,1900   0,38   17,2550   16,9900     601.990
# 14        ENDESA   17,9650   0,08   18,0950   17,8850     409.778
# 15     FERROVIAL   25,5800  -0,12   25,6400   25,4500     258.175
# 16       FLUIDRA   13,7500   0,73   13,8300   13,5700     425.660
# 17  GRIFOLS CL.A   10,2900  -1,44   10,6000   10,2650   1.120.966
# 18           IAG    1,5405  -1,15    1,5775    1,5360   7.851.493
# 19     IBERDROLA   10,9400   0,32   10,9750   10,8600   3.029.936
# 20       INDITEX   24,8700   0,40   25,0200   24,7200     891.591
# 21       INDRA A   10,3300   0,39   10,3600   10,2000     415.544
# 22  INM.COLONIAL    5,9850  -1,24    6,0250    5,9350     900.897
# 23        MAPFRE    1,8000  -0,28    1,8180    1,7880   2.333.488
# 24  MELIA HOTELS    5,0400  -0,49    5,1200    5,0400     524.955
# 25        MERLIN    9,0650   0,28    9,0850    8,9950     166.475
# 26       NATURGY   26,7000   0,15   26,7700   26,5600      53.997
# 27    PHARMA MAR   69,8800   0,87   70,2600   68,8200      49.175
# 28        R.E.C.   17,2500   0,70   17,2950   17,1000     224.599
# 29        REPSOL   14,1800  -2,34   14,3800   14,1400   3.569.426
# 30          ROVI   36,5000   0,44   36,6600   36,2000      77.086
# 31         SACYR    2,6300  -0,60    2,6800    2,6200   1.665.962
# 32  SIEMENS GAME   18,0250   0,06   18,0300   18,0200     563.832
# 33       SOLARIA   16,9450  -0,09   17,0850   16,7850     151.064
# 34    TELEFONICA    3,5230  -1,51    3,5780    3,5150  34.225.447
#
#    Efectivo (miles €)       Fecha      Hora
# 0            7.033,22  07/12/2022  17:20:12
# 1            3.566,64  07/12/2022  17:20:02
# 2            2.154,53  07/12/2022  17:20:14
# 3            4.709,06  07/12/2022  17:20:43
# 4           12.317,46  07/12/2022  17:20:20
# 5           11.164,26  07/12/2022  17:20:23
# 6            7.805,20  07/12/2022  17:20:43
# 7           47.702,77  07/12/2022  17:20:41
# 8            7.567,01  07/12/2022  17:20:19
# 9            7.544,66  07/12/2022  17:20:24
# 10          21.757,72  07/12/2022  17:20:36
# 11          18.222,38  07/12/2022  17:19:51
# 12          10.688,52  07/12/2022  17:20:22
# 13          10.293,61  07/12/2022  17:20:01
# 14           7.356,01  07/12/2022  17:20:23
# 15           6.589,95  07/12/2022  17:20:26
# 16           5.825,79  07/12/2022  17:20:48
# 17          11.657,25  07/12/2022  17:20:53
# 18          12.249,88  07/12/2022  17:20:51
# 19          33.086,24  07/12/2022  17:19:57
# 20          22.173,66  07/12/2022  17:20:32
# 21           4.279,50  07/12/2022  17:20:16
# 22           5.393,76  07/12/2022  17:20:41
# 23           4.193,39  07/12/2022  17:20:43
# 24           2.665,34  07/12/2022  17:20:42
# 25           1.505,06  07/12/2022  17:20:13
# 26           1.439,95  07/12/2022  17:20:28
# 27           3.428,69  07/12/2022  17:20:21
# 28           3.868,30  07/12/2022  17:20:55
# 29          50.884,59  07/12/2022  17:20:49
# 30           2.809,30  07/12/2022  17:19:55
# 31           4.413,62  07/12/2022  17:20:07
# 32          10.161,50  07/12/2022  17:20:02
# 33           2.559,09  07/12/2022  17:20:55
# 34         121.073,13  07/12/2022  17:20:42

# %% [markdown]
# ## Selenium

# %%
# Open browser
browser = Chrome()

# %%
# Get the page
browser.get(url)

# %%
# Get the links
links = browser.find_elements(By.LINK_TEXT, 'Acciones')

# %%
# Open the acciones webpage
links[0].click()

# %%
# Get the table of Acciones
table_acciones = browser.find_element(By.ID, 'ctl00_Contenido_tblAcciones')

# %%
# Parse columns and row values
values = []
for row in table_acciones.find_elements(By.TAG_NAME, 'tr'):
    if row.find_elements(By.TAG_NAME, 'th'):
        columns = [element.text for element in row.find_elements(By.TAG_NAME, 'th')]
    elif row.find_elements(By.TAG_NAME, 'td'):
        values.append([element.text for element in row.find_elements(By.TAG_NAME, 'td')])

# %%
# Save values into a dataframe
acciones = pd.DataFrame(values, columns=columns)

# %%
# View the dataframe
acciones
# Out:
#           Nombre      Últ. % Dif.      Máx.      Mín.     Volumen  \
# 0        ACCIONA  183,2000   0,66  183,8000  181,1000      38.972
# 1   ACCIONA ENER   37,4200   0,27   37,6200   37,0600      97.310
# 2       ACERINOX    9,3460  -1,25    9,4080    9,2860     230.827
# 3            ACS   27,2400   0,04   27,2900   27,0500     173.686
# 4           AENA  124,8500  -1,11  128,0500  124,4500      98.449
# 5        AMADEUS   50,4200  -0,12   50,8200   50,1600     221.311
# 6    ARCELORMIT.   25,3100  -1,52   25,5000   25,0050     309.135
# 7    B.SANTANDER    2,8065  -0,18    2,8320    2,7825  17.055.884
# 8    BA.SABADELL    0,8626   0,28    0,8736    0,8572   8.737.835
# 9      BANKINTER    5,9800  -0,17    6,0420    5,9080   1.265.997
# 10          BBVA    5,5280  -0,27    5,5550    5,4880   3.941.925
# 11     CAIXABANK    3,3610  -0,74    3,3980    3,3400   5.422.087
# 12       CELLNEX   33,1700  -0,60   33,4500   33,0500     322.900
# 13        ENAGAS   17,1950   0,41   17,2550   16,9900     602.231
# 14        ENDESA   17,9600   0,06   18,0950   17,8850     410.030
# 15     FERROVIAL   25,5800  -0,12   25,6400   25,4500     258.175
# 16       FLUIDRA   13,7600   0,81   13,8300   13,5700     428.934
# 17  GRIFOLS CL.A   10,2900  -1,44   10,6000   10,2650   1.124.049
# 18           IAG    1,5395  -1,22    1,5775    1,5360   7.890.151
# 19     IBERDROLA   10,9300   0,23   10,9750   10,8600   3.047.630
# 20       INDITEX   24,8600   0,36   25,0200   24,7200     894.168
# 21       INDRA A   10,3300   0,39   10,3600   10,2000     415.544
# 22  INM.COLONIAL    5,9850  -1,24    6,0250    5,9350     900.897
# 23        MAPFRE    1,8000  -0,28    1,8180    1,7880   2.337.529
# 24  MELIA HOTELS    5,0400  -0,49    5,1200    5,0400     526.392
# 25        MERLIN    9,0650   0,28    9,0850    8,9950     166.475
# 26       NATURGY   26,6900   0,11   26,7700   26,5600      55.218
# 27    PHARMA MAR   69,7200   0,64   70,2600   68,8200      49.665
# 28        R.E.C.   17,2450   0,67   17,2950   17,1000     228.154
# 29        REPSOL   14,1700  -2,41   14,3800   14,1400   3.576.574
# 30          ROVI   36,5000   0,44   36,6600   36,2000      77.086
# 31         SACYR    2,6300  -0,60    2,6800    2,6200   1.665.962
# 32  SIEMENS GAME   18,0250   0,06   18,0300   18,0200     563.832
# 33       SOLARIA   16,9400  -0,12   17,0850   16,7850     151.357
# 34    TELEFONICA    3,5230  -1,51    3,5780    3,5150  34.255.152
#
#    Efectivo (miles €)       Fecha      Hora
# 0            7.110,69  07/12/2022  17:21:30
# 1            3.628,22  07/12/2022  17:21:13
# 2            2.157,54  07/12/2022  17:21:11
# 3            4.715,46  07/12/2022  17:21:03
# 4           12.395,50  07/12/2022  17:21:26
# 5           11.175,86  07/12/2022  17:21:04
# 6            7.805,20  07/12/2022  17:20:43
# 7           47.788,65  07/12/2022  17:21:38
# 8            7.568,83  07/12/2022  17:21:04
# 9            7.549,15  07/12/2022  17:21:04
# 10          21.778,15  07/12/2022  17:21:17
# 11          18.229,25  07/12/2022  17:21:04
# 12          10.733,71  07/12/2022  17:21:31
# 13          10.297,75  07/12/2022  17:21:29
# 14           7.360,54  07/12/2022  17:21:13
# 15           6.589,95  07/12/2022  17:20:26
# 16           5.870,84  07/12/2022  17:21:30
# 17          11.688,98  07/12/2022  17:21:15
# 18          12.309,41  07/12/2022  17:21:25
# 19          33.279,63  07/12/2022  17:21:24
# 20          22.237,72  07/12/2022  17:21:18
# 21           4.279,50  07/12/2022  17:20:16
# 22           5.393,76  07/12/2022  17:20:41
# 23           4.200,66  07/12/2022  17:21:10
# 24           2.672,59  07/12/2022  17:21:29
# 25           1.505,06  07/12/2022  17:20:13
# 26           1.472,56  07/12/2022  17:21:14
# 27           3.462,88  07/12/2022  17:21:24
# 28           3.929,60  07/12/2022  17:21:11
# 29          50.985,90  07/12/2022  17:21:15
# 30           2.809,30  07/12/2022  17:19:55
# 31           4.413,62  07/12/2022  17:20:07
# 32          10.161,50  07/12/2022  17:20:02
# 33           2.564,05  07/12/2022  17:21:18
# 34         121.177,78  07/12/2022  17:21:38

# %% [markdown]
# # Exercici 2

# %% [markdown]
# Documenta en un word el teu conjunt de dades generat amb la informació que tenen els diferents arxius de Kaggle.

# %% [markdown]
# ### Títol
#
# Accions del IBEX-35 24/01/2022
#
# ### Descripció
#
# Accions de les 35 companyies del IBEX-35 del dia 24/01/2022
#
# ### Llicència
#
# [CC0: Public Domain](https://creativecommons.org/publicdomain/zero/1.0/)
#
# ### Context
#
# El IBEX-35 (Índice Bursátil Español) és l'índex borsari de referència de la Bolsa de Madrid (Bolsa de Madrid) i està format per 35 empreses. Aquest conjunt de dades conté la història del 24 de gener del 2022.
#
# ### Content
# Head of the dataset:
# <img src="acciones_head.png" width="700px">
#
# ### Acknowledgements
#
# Origen: https://www.bolsamadrid.es/esp/aspx/Mercados/Precios.aspx?indice=ESI100000000

# %% [markdown]
# # Exercici 3

# %% [markdown]
# Tria una página web que tu vulguis i realitza web scraping mitjançant la llibreria Scrapy.

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'http://quotes.toscrape.com/page/1/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        page = response.url.split('/')[-2]
        filename = f'quotes/quotes-{page}.txt'
        with open(filename, 'w') as fw:
            for quote in response.css('div.quote'):
                author = quote.xpath('span/small/text()').get()
                quote = quote.css('span.text::text').get()
                fw.write(f"{author}: {quote}\n")
        self.log(f'Saved file {filename}')
        
        next_page = response.css('li.next a::attr("href")').get()
        if next_page is not None:
            yield response.follow(next_page, self.parse)

# %%
# Initialize the crawler
process = CrawlerProcess()

# Specify the spider to use
process.crawl(QuotesSpider)

# Start the crawling process
process.start()
# Out:
# 2022-12-07 17:37:22 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: scrapybot)
# 2022-12-07 17:37:22 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.0, Twisted 22.10.0, Python 3.10.5 (v3.10.5:f377153967, Jun  6 2022, 12:36:10) [Clang 13.0.0 (clang-1300.0.29.30)], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.4, Platform macOS-13.0.1-arm64-arm-64bit
# 2022-12-07 17:37:22 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2022-12-07 17:37:22 [py.warnings] WARNING: /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2022-12-07 17:37:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-12-07 17:37:22 [scrapy.extensions.telnet] INFO: Telnet Password: 10a3fc99d28665f2
# 2022-12-07 17:37:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-12-07 17:37:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-12-07 17:37:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-12-07 17:37:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-12-07 17:37:22 [scrapy.core.engine] INFO: Spider opened
# 2022-12-07 17:37:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-12-07 17:37:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-12-07 17:37:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/1/> (referer: None)
# 2022-12-07 17:37:22 [quotes] DEBUG: Saved file quotes/quotes-1.txt
# 2022-12-07 17:37:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/2/> (referer: http://quotes.toscrape.com/page/1/)
# 2022-12-07 17:37:23 [quotes] DEBUG: Saved file quotes/quotes-2.txt
# 2022-12-07 17:37:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/3/> (referer: http://quotes.toscrape.com/page/2/)
# 2022-12-07 17:37:23 [quotes] DEBUG: Saved file quotes/quotes-3.txt
# 2022-12-07 17:37:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/4/> (referer: http://quotes.toscrape.com/page/3/)
# 2022-12-07 17:37:23 [quotes] DEBUG: Saved file quotes/quotes-4.txt
# 2022-12-07 17:37:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/5/> (referer: http://quotes.toscrape.com/page/4/)
# 2022-12-07 17:37:24 [quotes] DEBUG: Saved file quotes/quotes-5.txt
# 2022-12-07 17:37:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/6/> (referer: http://quotes.toscrape.com/page/5/)
# 2022-12-07 17:37:24 [quotes] DEBUG: Saved file quotes/quotes-6.txt
# 2022-12-07 17:37:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/7/> (referer: http://quotes.toscrape.com/page/6/)
# 2022-12-07 17:37:24 [quotes] DEBUG: Saved file quotes/quotes-7.txt
# 2022-12-07 17:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/8/> (referer: http://quotes.toscrape.com/page/7/)
# 2022-12-07 17:37:25 [quotes] DEBUG: Saved file quotes/quotes-8.txt
# 2022-12-07 17:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/9/> (referer: http://quotes.toscrape.com/page/8/)
# 2022-12-07 17:37:25 [quotes] DEBUG: Saved file quotes/quotes-9.txt
# 2022-12-07 17:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://quotes.toscrape.com/page/10/> (referer: http://quotes.toscrape.com/page/9/)
# 2022-12-07 17:37:25 [quotes] DEBUG: Saved file quotes/quotes-10.txt
# 2022-12-07 17:37:25 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-12-07 17:37:25 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2666,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 109750,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 10,
#  'elapsed_time_seconds': 3.314654,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 7, 16, 37, 25, 830535),
#  'log_count/DEBUG': 21,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 142475264,
#  'memusage/startup': 142475264,
#  'request_depth_max': 9,
#  'response_received_count': 10,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2022, 12, 7, 16, 37, 22, 515881)}
# 2022-12-07 17:37:25 [scrapy.core.engine] INFO: Spider closed (finished)
