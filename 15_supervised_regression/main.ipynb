# %% [markdown]
# # Aprenentatge Supervisat - Regressions

# %%
import io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, PowerTransformer 
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.tree import DecisionTreeRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# %%
pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# # Exercici 1

# %% [markdown]
# Crea almenys tres models de regressió diferents per intentar predir el millor possible l’endarreriment dels vols (ArrDelay) de DelayedFlights.csv.

# %% [markdown]
# ### Dataset

# %%
# Load the dataframe
url = 'https://www.dropbox.com/s/477prm0zakkxkga/DelayedFlights.csv?dl=1'
s = requests.get(url).content
df = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
# View the dataset
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# 0           0  2008      1           3          4 2003.0000        1955
# 1           1  2008      1           3          4  754.0000         735
# 2           2  2008      1           3          4  628.0000         620
# 3           4  2008      1           3          4 1829.0000        1755
# 4           5  2008      1           3          4 1940.0000        1915
#
#     ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0 2211.0000        2225            WN  ...  4.0000  8.0000          0
# 1 1002.0000        1000            WN  ...  5.0000 10.0000          0
# 2  804.0000         750            WN  ...  3.0000 17.0000          0
# 3 1959.0000        1925            WN  ...  3.0000 10.0000          0
# 4 2121.0000        2110            WN  ...  4.0000 10.0000          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                 N         0           NaN           NaN      NaN
# 1                 N         0           NaN           NaN      NaN
# 2                 N         0           NaN           NaN      NaN
# 3                 N         0        2.0000        0.0000   0.0000
# 4                 N         0           NaN           NaN      NaN
#
#   SecurityDelay  LateAircraftDelay
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3        0.0000            32.0000
# 4           NaN                NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# Les columnes que conté són:
# - **Unnamed**: índex
# - **Year**: any del vol
# - **Month**: mes del vol
# - **DayofMonth**: dia del vol
# - **DayOfWeek**: dia de la setmana del vol
# - **DepTime**: hora de sortida del vol real
# - **CRSDepTime**: hora de sortida del vol programada
# - **ArrTime**: hora d'arribada del vol real
# - **CRSArrTime**: hora d'arribada del vol programada
# - **UniqueCarrier**: aerolínea
# - **FlightNum**: número de vol
# - **TailNum**: número de cua de l'avió
# - **ActualElapsedTime**: temps de vol real en minuts
# - **CRSElapsedTime**: temps de vol programat en minuts
# - **AirTime**: temps en l'aire en minuts
# - **ArrDelay**: retràs en l'hora d'arribada en minuts
# - **DepDelay**: retràs en l'hora de sortida en minuts
# - **Origin**: aeroport de sortida
# - **Dest**: aeroport de destinació
# - **Distance**: distància del vol
# - **Taxiln**: temps de taxi de l'arribada en minuts
# - **TaxiOut**: temps de taxi de la sortida en minuts
# - **Cancelled**: cancel·lació
# - **CancellationCode**: codi de cancel·lació
# - **Diverted**: desviat
# - **CarrierDelay**: retràs atribuït a l'aerolínea en minuts
# - **WeatherDelay**: retràs atribuït al clima en minuts
# - **NASDelay**: retràs atribuït al sistema d'aviació nacional en minuts
# - **SecurityDelay**: retràs atribuït a la seguretat en minuts
# - **LateAircraftDelay**: retràs atribuït a l'arribada amb retràs d'un avió en minuts

# %%
# Column description
df.describe(include='all').T
# Out:
#                          count unique     top     freq         mean  \
# Unnamed: 0        1936758.0000    NaN     NaN      NaN 3341651.1513
# Year              1936758.0000    NaN     NaN      NaN    2008.0000
# Month             1936758.0000    NaN     NaN      NaN       6.1111
# DayofMonth        1936758.0000    NaN     NaN      NaN      15.7535
# DayOfWeek         1936758.0000    NaN     NaN      NaN       3.9848
# DepTime           1936758.0000    NaN     NaN      NaN    1518.5341
# CRSDepTime        1936758.0000    NaN     NaN      NaN    1467.4726
# ArrTime           1929648.0000    NaN     NaN      NaN    1610.1406
# CRSArrTime        1936758.0000    NaN     NaN      NaN    1634.2246
# UniqueCarrier          1936758     20      WN   377602          NaN
# FlightNum         1936758.0000    NaN     NaN      NaN    2184.2632
# TailNum                1936753   5366  N325SW      965          NaN
# ActualElapsedTime 1928371.0000    NaN     NaN      NaN     133.3059
# CRSElapsedTime    1936560.0000    NaN     NaN      NaN     134.3027
# AirTime           1928371.0000    NaN     NaN      NaN     108.2771
# ArrDelay          1928371.0000    NaN     NaN      NaN      42.1999
# DepDelay          1936758.0000    NaN     NaN      NaN      43.1852
# Origin                 1936758    303     ATL   131613          NaN
# Dest                   1936758    304     ORD   108984          NaN
# Distance          1936758.0000    NaN     NaN      NaN     765.6862
# TaxiIn            1929648.0000    NaN     NaN      NaN       6.8130
# TaxiOut           1936303.0000    NaN     NaN      NaN      18.2322
# Cancelled         1936758.0000    NaN     NaN      NaN       0.0003
# CancellationCode       1936758      4       N  1936125          NaN
# Diverted          1936758.0000    NaN     NaN      NaN       0.0040
# CarrierDelay      1247488.0000    NaN     NaN      NaN      19.1794
# WeatherDelay      1247488.0000    NaN     NaN      NaN       3.7036
# NASDelay          1247488.0000    NaN     NaN      NaN      15.0216
# SecurityDelay     1247488.0000    NaN     NaN      NaN       0.0901
# LateAircraftDelay 1247488.0000    NaN     NaN      NaN      25.2965
#
#                            std       min          25%          50%  \
# Unnamed: 0        2066064.9575    0.0000 1517452.5000 3242558.0000
# Year                    0.0000 2008.0000    2008.0000    2008.0000
# Month                   3.4825    1.0000       3.0000       6.0000
# DayofMonth              8.7763    1.0000       8.0000      16.0000
# DayOfWeek               1.9960    1.0000       2.0000       4.0000
# DepTime               450.4853    1.0000    1203.0000    1545.0000
# CRSDepTime            424.7668    0.0000    1135.0000    1510.0000
# ArrTime               548.1781    1.0000    1316.0000    1715.0000
# CRSArrTime            464.6347    0.0000    1325.0000    1705.0000
# UniqueCarrier              NaN       NaN          NaN          NaN
# FlightNum            1944.7023    1.0000     610.0000    1543.0000
# TailNum                    NaN       NaN          NaN          NaN
# ActualElapsedTime      72.0601   14.0000      80.0000     116.0000
# CRSElapsedTime         71.3414  -25.0000      82.0000     116.0000
# AirTime                68.6426    0.0000      58.0000      90.0000
# ArrDelay               56.7847 -109.0000       9.0000      24.0000
# DepDelay               53.4025    6.0000      12.0000      24.0000
# Origin                     NaN       NaN          NaN          NaN
# Dest                       NaN       NaN          NaN          NaN
# Distance              574.4797   11.0000     338.0000     606.0000
# TaxiIn                  5.2736    0.0000       4.0000       6.0000
# TaxiOut                14.3385    0.0000      10.0000      14.0000
# Cancelled               0.0181    0.0000       0.0000       0.0000
# CancellationCode           NaN       NaN          NaN          NaN
# Diverted                0.0631    0.0000       0.0000       0.0000
# CarrierDelay           43.5462    0.0000       0.0000       2.0000
# WeatherDelay           21.4929    0.0000       0.0000       0.0000
# NASDelay               33.8331    0.0000       0.0000       2.0000
# SecurityDelay           2.0227    0.0000       0.0000       0.0000
# LateAircraftDelay      42.0549    0.0000       0.0000       8.0000
#
#                            75%          max
# Unnamed: 0        4972466.7500 7009727.0000
# Year                 2008.0000    2008.0000
# Month                   9.0000      12.0000
# DayofMonth             23.0000      31.0000
# DayOfWeek               6.0000       7.0000
# DepTime              1900.0000    2400.0000
# CRSDepTime           1815.0000    2359.0000
# ArrTime              2030.0000    2400.0000
# CRSArrTime           2014.0000    2400.0000
# UniqueCarrier              NaN          NaN
# FlightNum            3422.0000    9742.0000
# TailNum                    NaN          NaN
# ActualElapsedTime     165.0000    1114.0000
# CRSElapsedTime        165.0000     660.0000
# AirTime               137.0000    1091.0000
# ArrDelay               56.0000    2461.0000
# DepDelay               53.0000    2467.0000
# Origin                     NaN          NaN
# Dest                       NaN          NaN
# Distance              998.0000    4962.0000
# TaxiIn                  8.0000     240.0000
# TaxiOut                21.0000     422.0000
# Cancelled               0.0000       1.0000
# CancellationCode           NaN          NaN
# Diverted                0.0000       1.0000
# CarrierDelay           21.0000    2436.0000
# WeatherDelay            0.0000    1352.0000
# NASDelay               15.0000    1357.0000
# SecurityDelay           0.0000     392.0000
# LateAircraftDelay      33.0000    1316.0000

# %% [markdown]
# Com podem observar, tenim 5 columnes categòriques: UniqueCarrier amb 20 valors únics, Origin amb 303, Dest amb 304, TailNum amb 5367 i CancellationCode amb 4. Per a poder utilizar tota aquesta informació en un model de regressió, caldria convertir-ho a informació numèrica amb un mètode com one hot encoding o similar. Però això fa augmentar el nostre dataset a més de 6000 variables i se'ns fa difícil treballar-hi. Per això, en aquesta primera part, no considerem les variables categòriques.
# A més a més, tampoc tindrem en compte la columan Unnamed que correspon a un índex. Així doncs, elimminarem aquestes columnes per a extreure les features.

# %%
# Get the target variable
target = 'ArrDelay'

# %%
# Get the dependent variable set
y = df[target]

# %%
# Get the numerical features
features = df.select_dtypes(include=np.number).columns.tolist()
features.remove('Unnamed: 0')
features.remove(target)

# %% [markdown]
# ### Missing values

# %%
# Number of missing values per column
df[features].isnull().sum()
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# FlightNum                 0
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# DepDelay                  0
# Distance                  0
# TaxiIn                 7110
# TaxiOut                 455
# Cancelled                 0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
# Get the feature columns with nulls
null_cols = df[features+[target]].isnull().sum().rename_axis('name').reset_index(name='nulls')
null_cols = null_cols[null_cols.nulls>0].name.tolist()

# %%
# Imputation of missing values with the median of the feature 
for col in null_cols:
    df[col].fillna(df[col].median(), inplace = True)

# %%
# Get the independent variable set
X = df[features]

# %% [markdown]
# ### Feature correlation

# %%
df[features + [target]].corr()[target]
# Out:
# Year                    NaN
# Month               -0.0012
# DayofMonth           0.0041
# DayOfWeek            0.0061
# DepTime              0.1268
# CRSDepTime           0.0445
# ArrTime             -0.0511
# CRSArrTime           0.0430
# FlightNum            0.0611
# ActualElapsedTime    0.0684
# CRSElapsedTime      -0.0161
# AirTime              0.0002
# DepDelay             0.9477
# Distance            -0.0302
# TaxiIn               0.1561
# TaxiOut              0.2849
# Cancelled           -0.0058
# Diverted            -0.0203
# CarrierDelay         0.5353
# WeatherDelay         0.2779
# NASDelay             0.4375
# SecurityDelay        0.0112
# LateAircraftDelay    0.5192
# ArrDelay             1.0000
# Name: ArrDelay, dtype: float64

# %% [markdown]
# ### Feature multicollinearity

# %%
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature       VIF
# 9   ActualElapsedTime 3027.4425
# 11            AirTime 2785.8932
# 15            TaxiOut  118.9076
# 10     CRSElapsedTime   79.3807
# 0                Year   40.0045
# 12           DepDelay   39.9158
# 13           Distance   35.1015
# 18       CarrierDelay   19.9635
# 22  LateAircraftDelay   18.8409
# 14             TaxiIn   17.1235
# 20           NASDelay   11.7019
# 19       WeatherDelay    5.2988
# 4             DepTime    5.1799
# 5          CRSDepTime    5.1008
# 7          CRSArrTime    2.8961
# 6             ArrTime    1.7163
# 8           FlightNum    1.1700
# 17           Diverted    1.1059
# 21      SecurityDelay    1.0417
# 16          Cancelled    1.0324
# 1               Month    1.0063
# 2          DayofMonth    1.0040
# 3           DayOfWeek    1.0018

# %% [markdown]
# Observem que tenim un gran número de variables amb un VIF molt elevat. El que farem és eliminar d'una en una les variables amb el VIF més elevat fins a obtindre un coeficient acceptable. Primer de tot eliminarem ActualElapsedTime.

# %%
# Remove the feature with the highest VIF
del X['ActualElapsedTime']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 9      CRSElapsedTime 79.2639
# 10            AirTime 60.9782
# 0                Year 39.9867
# 11           DepDelay 39.6405
# 12           Distance 35.0897
# 17       CarrierDelay 19.8277
# 21  LateAircraftDelay 18.7146
# 19           NASDelay 11.6049
# 18       WeatherDelay  5.2656
# 4             DepTime  5.1799
# 5          CRSDepTime  5.1008
# 14            TaxiOut  3.4822
# 7          CRSArrTime  2.8961
# 6             ArrTime  1.7163
# 13             TaxiIn  1.3554
# 8           FlightNum  1.1700
# 16           Diverted  1.0987
# 20      SecurityDelay  1.0414
# 15          Cancelled  1.0291
# 1               Month  1.0063
# 2          DayofMonth  1.0040
# 3           DayOfWeek  1.0018

# %%
# Remove the feature with the highest VIF
del X['CRSElapsedTime']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 0                Year 37.3700
# 11           Distance 26.9281
# 9             AirTime 26.3451
# 10           DepDelay 24.0453
# 16       CarrierDelay 12.2855
# 20  LateAircraftDelay 11.6652
# 18           NASDelay  6.9220
# 4             DepTime  5.1798
# 5          CRSDepTime  5.0965
# 17       WeatherDelay  3.5304
# 7          CRSArrTime  2.8893
# 13            TaxiOut  2.0482
# 6             ArrTime  1.7162
# 8           FlightNum  1.1682
# 12             TaxiIn  1.1547
# 15           Diverted  1.0984
# 19      SecurityDelay  1.0234
# 14          Cancelled  1.0189
# 1               Month  1.0059
# 2          DayofMonth  1.0040
# 3           DayOfWeek  1.0018

# %%
# Remove the feature with the highest VIF
del X['Year']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 8             AirTime 86.0796
# 10           Distance 72.0623
# 3             DepTime 64.0369
# 4          CRSDepTime 63.7871
# 6          CRSArrTime 38.4412
# 9            DepDelay 38.3216
# 5             ArrTime 16.0311
# 19  LateAircraftDelay 14.7478
# 15       CarrierDelay 13.5501
# 17           NASDelay  7.5166
# 12            TaxiOut  5.0240
# 2           DayOfWeek  4.5146
# 1          DayofMonth  3.9198
# 0               Month  3.8013
# 16       WeatherDelay  3.4957
# 11             TaxiIn  2.9350
# 7           FlightNum  2.4189
# 14           Diverted  1.1027
# 18      SecurityDelay  1.0244
# 13          Cancelled  1.0181

# %%
# Remove the feature with the highest VIF
del X['AirTime']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 3             DepTime 63.8961
# 4          CRSDepTime 63.7602
# 6          CRSArrTime 38.3661
# 8            DepDelay 35.1347
# 5             ArrTime 15.9201
# 18  LateAircraftDelay 13.5710
# 14       CarrierDelay 12.4382
# 16           NASDelay  6.7305
# 11            TaxiOut  4.9309
# 2           DayOfWeek  4.4934
# 1          DayofMonth  3.8982
# 0               Month  3.7901
# 15       WeatherDelay  3.2667
# 9            Distance  3.0354
# 10             TaxiIn  2.9339
# 7           FlightNum  2.3778
# 13           Diverted  1.0934
# 17      SecurityDelay  1.0216
# 12          Cancelled  1.0167

# %%
# Remove the feature with the highest VIF
del X['DepTime']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 5          CRSArrTime 37.5255
# 7            DepDelay 34.9948
# 3          CRSDepTime 24.6775
# 4             ArrTime 15.4926
# 17  LateAircraftDelay 13.5639
# 13       CarrierDelay 12.4347
# 15           NASDelay  6.7305
# 10            TaxiOut  4.9288
# 2           DayOfWeek  4.4934
# 1          DayofMonth  3.8982
# 0               Month  3.7901
# 14       WeatherDelay  3.2648
# 8            Distance  3.0227
# 9              TaxiIn  2.9338
# 6           FlightNum  2.3766
# 12           Diverted  1.0934
# 16      SecurityDelay  1.0216
# 11          Cancelled  1.0167

# %%
# Remove the feature with the highest VIF
del X['CRSArrTime']
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 6            DepDelay 34.8728
# 16  LateAircraftDelay 13.5521
# 3          CRSDepTime 13.0734
# 12       CarrierDelay 12.4033
# 4             ArrTime 10.6877
# 14           NASDelay  6.7119
# 9             TaxiOut  4.8995
# 2           DayOfWeek  4.4908
# 1          DayofMonth  3.8961
# 0               Month  3.7856
# 13       WeatherDelay  3.2602
# 7            Distance  2.9948
# 8              TaxiIn  2.9285
# 5           FlightNum  2.3763
# 11           Diverted  1.0933
# 15      SecurityDelay  1.0215
# 10          Cancelled  1.0166

# %% [markdown]
# Ara hauriem d'eliminar la feature DepDelay però això ho deixarem per l'últim exercici. Així doncs, haurem eliminat:
# - ActualElapsedTime
# - CRSElapsedTime
# - Year
# - AirTime
# - DepTime
# - CRSArrTime

# %%
features = list(set(features) - set({'ActualElapsedTime', 'CRSElapsedTime', 'Year', 'AirTime', 'DepTime', 'CRSArrTime'}))

# %% [markdown]
# ### Train and test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
predictions = pd.DataFrame({'Actual': y_test})

# %%
model = pd.DataFrame(index=['intercept'] + X.columns.tolist())

# %%
metrics = pd.DataFrame(index=['R2', 'Mean Absolute Error', 'Mean Squared Error', 'Root Mean Squared Error'])

# %%
feature_importance = pd.DataFrame(index=X.columns.tolist())

# %% [markdown]
# ### Linear regression

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the predictions
predictions['Linear'] = y_pred

# Save the intercept and coefficients
model['Linear'] = [regr.intercept_] + regr.coef_.tolist()

# Save the metrics
metrics['Linear'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Linear'] = abs(regr.coef_)

# %%
# View the predictions
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Out:
#           Actual  Predicted
# 595091    9.0000     7.8372
# 699277   -3.0000     7.2816
# 513280   13.0000     7.6456
# 555111   11.0000     7.8773
# 1269142  19.0000    13.3803
# ...          ...        ...
# 1417777  23.0000    17.6895
# 67042    59.0000    58.1246
# 1311116  32.0000    28.1329
# 573072  134.0000   134.8619
# 740252    5.0000     6.9668
#
# [581028 rows x 2 columns]

# %%
# The intercept
regr.intercept_
# Out:
# -5.549497420161785

# %%
# The coefficients
regr.coef_
# Out:
# array([-4.31677574e-02, -2.06706610e-03, -1.74599259e-02,  2.54805620e-04,
#         7.27868466e-06, -6.64069188e-07,  8.37640088e-02, -1.86671180e-03,
#         1.28058176e-01,  1.07971239e-01,  8.99987353e+00,  1.16212078e+01,
#         9.45587939e-01,  9.37561586e-01,  9.46476247e-01,  1.00145929e+00,
#         9.45363075e-01])

# %%
# Performance metrics
print('Coefficient of determination:', r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.9900097524224886
# Mean Absolute Error: 3.988308407368507
# Mean Squared Error: 32.25956685001038
# Root Mean Squared Error: 5.679750597518379

# %%
# Plot test vs predicted y
plt.scatter(y_test, y_pred, color='black', alpha=0.5)
plt.plot([0, 2000], [0, 2000], color='blue');

# %%
# Feature importance
pd.DataFrame({'Feature': X.columns, 'Importance': abs(regr.coef_)}).sort_values('Importance', ascending=False)
# Out:
#               Feature  Importance
# 11           Diverted     11.6212
# 10          Cancelled      8.9999
# 15      SecurityDelay      1.0015
# 14           NASDelay      0.9465
# 12       CarrierDelay      0.9456
# 16  LateAircraftDelay      0.9454
# 13       WeatherDelay      0.9376
# 8              TaxiIn      0.1281
# 9             TaxiOut      0.1080
# 6            DepDelay      0.0838
# 0               Month      0.0432
# 2           DayOfWeek      0.0175
# 1          DayofMonth      0.0021
# 7            Distance      0.0019
# 3          CRSDepTime      0.0003
# 4             ArrTime      0.0000
# 5           FlightNum      0.0000

# %% [markdown]
# ### Linear regression with statsmodel

# %%
X_train_const = sm.add_constant(X_train)
result = sm.OLS(y_train, X_train_const).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ArrDelay   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 7.873e+06
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):               0.00
# Time:                        16:31:37   Log-Likelihood:            -4.2759e+06
# No. Observations:             1355730   AIC:                         8.552e+06
# Df Residuals:                 1355712   BIC:                         8.552e+06
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -5.5495      0.029   -193.477      0.000      -5.606      -5.493
# Month                -0.0432      0.001    -30.803      0.000      -0.046      -0.040
# DayofMonth           -0.0021      0.001     -3.718      0.000      -0.003      -0.001
# DayOfWeek            -0.0175      0.002     -7.152      0.000      -0.022      -0.013
# CRSDepTime            0.0003   1.28e-05     19.970      0.000       0.000       0.000
# ArrTime            7.279e-06   9.79e-06      0.744      0.457   -1.19e-05    2.65e-05
# FlightNum         -6.641e-07    2.7e-06     -0.246      0.806   -5.96e-06    4.63e-06
# DepDelay              0.0838      0.000    197.595      0.000       0.083       0.085
# Distance             -0.0019   9.22e-06   -202.520      0.000      -0.002      -0.002
# TaxiIn                0.1281      0.001    129.358      0.000       0.126       0.130
# TaxiOut               0.1080      0.000    226.573      0.000       0.107       0.109
# Cancelled             8.9999      0.269     33.509      0.000       8.473       9.526
# Diverted             11.6212      0.081    143.975      0.000      11.463      11.779
# CarrierDelay          0.9456      0.000   2087.612      0.000       0.945       0.946
# WeatherDelay          0.9376      0.001   1857.518      0.000       0.937       0.939
# NASDelay              0.9465      0.000   2200.455      0.000       0.946       0.947
# SecurityDelay         1.0015      0.003    335.530      0.000       0.996       1.007
# LateAircraftDelay     0.9454      0.000   2072.713      0.000       0.944       0.946
# ==============================================================================
# Omnibus:                   642051.151   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4086114.189
# Skew:                          -2.221   Prob(JB):                         0.00
# Kurtosis:                      10.253   Cond. No.                     1.93e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Ridge regression

# %%
# Create the Ridge regressor
regr = Ridge(random_state=1)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the predictions
predictions['Ridge'] = y_pred

# Save the intercept and coefficients
model['Ridge'] = [regr.intercept_] + regr.coef_.tolist()

# Save the metrics
metrics['Ridge'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Ridge'] = abs(regr.coef_)

# %%
# View the predictions
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Out:
#           Actual  Predicted
# 595091    9.0000     7.8372
# 699277   -3.0000     7.2816
# 513280   13.0000     7.6457
# 555111   11.0000     7.8773
# 1269142  19.0000    13.3803
# ...          ...        ...
# 1417777  23.0000    17.6897
# 67042    59.0000    58.1246
# 1311116  32.0000    28.1329
# 573072  134.0000   134.8619
# 740252    5.0000     6.9667
#
# [581028 rows x 2 columns]

# %%
# The intercept
regr.intercept_
# Out:
# -5.549577888875298

# %%
# The coefficients
regr.coef_
# Out:
# array([-4.31650238e-02, -2.06690817e-03, -1.74596666e-02,  2.54786454e-04,
#         7.28212338e-06, -6.64165238e-07,  8.37717040e-02, -1.86672697e-03,
#         1.28062637e-01,  1.07976780e-01,  8.97941191e+00,  1.16186161e+01,
#         9.45579935e-01,  9.37553785e-01,  9.46469068e-01,  1.00145091e+00,
#         9.45355050e-01])

# %%
# Performance metrics
print('Coefficient of determination:', r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.9900097476808628
# Mean Absolute Error: 3.988306700016201
# Mean Squared Error: 32.259582161221886
# Root Mean Squared Error: 5.679751945395317

# %%
# Plot test vs predicted y
plt.scatter(y_test, y_pred, color='black', alpha=0.5)
plt.plot([0, 2000], [0, 2000], color='blue');

# %%
# Feature importance
pd.DataFrame({'Feature': X.columns, 'Importance': abs(regr.coef_)}).sort_values('Importance', ascending=False)
# Out:
#               Feature  Importance
# 11           Diverted     11.6186
# 10          Cancelled      8.9794
# 15      SecurityDelay      1.0015
# 14           NASDelay      0.9465
# 12       CarrierDelay      0.9456
# 16  LateAircraftDelay      0.9454
# 13       WeatherDelay      0.9376
# 8              TaxiIn      0.1281
# 9             TaxiOut      0.1080
# 6            DepDelay      0.0838
# 0               Month      0.0432
# 2           DayOfWeek      0.0175
# 1          DayofMonth      0.0021
# 7            Distance      0.0019
# 3          CRSDepTime      0.0003
# 4             ArrTime      0.0000
# 5           FlightNum      0.0000

# %% [markdown]
# ### Lasso regression

# %%
# Create the Lasso regressor
regr = Lasso(random_state=1)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the predictions
predictions['Lasso'] = y_pred

# Save the intercept and coefficients
model['Lasso'] = [regr.intercept_] + regr.coef_.tolist()

# Save the metrics
metrics['Lasso'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Lasso'] = abs(regr.coef_)

# %%
# View the predictions
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Out:
#           Actual  Predicted
# 595091    9.0000     8.1030
# 699277   -3.0000     6.9787
# 513280   13.0000     7.9639
# 555111   11.0000     7.8861
# 1269142  19.0000    13.3573
# ...          ...        ...
# 1417777  23.0000    18.4663
# 67042    59.0000    56.3559
# 1311116  32.0000    28.0173
# 573072  134.0000   134.5330
# 740252    5.0000     6.5370
#
# [581028 rows x 2 columns]

# %%
# The intercept
regr.intercept_
# Out:
# -5.86373324998177

# %%
# The coefficients
regr.coef_
# Out:
# array([-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  1.32146881e-04,
#         1.61570318e-05, -2.71584812e-06,  1.22197919e-01, -1.89919765e-03,
#         1.13774407e-01,  1.30827297e-01,  0.00000000e+00,  0.00000000e+00,
#         9.04957304e-01,  8.96150925e-01,  9.12260982e-01,  5.93380877e-01,
#         9.04735366e-01])

# %%
# Performance metrics
print('Coefficient of determination:', r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.9896920329342014
# Mean Absolute Error: 4.017693800512023
# Mean Squared Error: 33.28551670685129
# Root Mean Squared Error: 5.76936016442476

# %%
# Plot test vs predicted y
plt.scatter(y_test, y_pred, color='black', alpha=0.5)
plt.plot([0, 2000], [0, 2000], color='blue');

# %%
# Feature importance
pd.DataFrame({'Feature': X.columns, 'Importance': abs(regr.coef_)}).sort_values('Importance', ascending=False)
# Out:
#               Feature  Importance
# 14           NASDelay      0.9123
# 12       CarrierDelay      0.9050
# 16  LateAircraftDelay      0.9047
# 13       WeatherDelay      0.8962
# 15      SecurityDelay      0.5934
# 9             TaxiOut      0.1308
# 6            DepDelay      0.1222
# 8              TaxiIn      0.1138
# 7            Distance      0.0019
# 3          CRSDepTime      0.0001
# 4             ArrTime      0.0000
# 5           FlightNum      0.0000
# 1          DayofMonth      0.0000
# 10          Cancelled      0.0000
# 11           Diverted      0.0000
# 2           DayOfWeek      0.0000
# 0               Month      0.0000

# %% [markdown]
# ### ElasticNet regression

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=1)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the predictions
predictions['ElasticNet'] = y_pred

# Save the intercept and coefficients
model['ElasticNet'] = [regr.intercept_] + regr.coef_.tolist()

# Save the metrics
metrics['ElasticNet'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['ElasticNet'] = abs(regr.coef_)

# %%
# View the predictions
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Out:
#           Actual  Predicted
# 595091    9.0000     8.0423
# 699277   -3.0000     7.1478
# 513280   13.0000     8.0502
# 555111   11.0000     7.8827
# 1269142  19.0000    13.2797
# ...          ...        ...
# 1417777  23.0000    18.4524
# 67042    59.0000    57.1595
# 1311116  32.0000    27.9762
# 573072  134.0000   134.5538
# 740252    5.0000     6.4578
#
# [581028 rows x 2 columns]

# %%
# The intercept
regr.intercept_
# Out:
# -6.027418686440505

# %%
# The coefficients
regr.coef_
# Out:
# array([-3.03834736e-03, -0.00000000e+00, -0.00000000e+00,  1.37598078e-04,
#         8.14222301e-06, -5.62573303e-06,  1.26421566e-01, -1.93108271e-03,
#         1.33277565e-01,  1.36488868e-01,  0.00000000e+00,  0.00000000e+00,
#         9.00630195e-01,  8.91787938e-01,  9.07172047e-01,  6.52912659e-01,
#         9.00340844e-01])

# %%
# Performance metrics
print('Coefficient of determination:', r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.9897253607499009
# Mean Absolute Error: 4.016411141500627
# Mean Squared Error: 33.177897662359975
# Root Mean Squared Error: 5.760025838688571

# %%
# Plot test vs predicted y
plt.scatter(y_test, y_pred, color='black', alpha=0.5)
plt.plot([0, 2000], [0, 2000], color='blue');

# %%
# Feature importance
pd.DataFrame({'Feature': X.columns, 'Importance': abs(regr.coef_)}).sort_values('Importance', ascending=False)
# Out:
#               Feature  Importance
# 14           NASDelay      0.9072
# 12       CarrierDelay      0.9006
# 16  LateAircraftDelay      0.9003
# 13       WeatherDelay      0.8918
# 15      SecurityDelay      0.6529
# 9             TaxiOut      0.1365
# 8              TaxiIn      0.1333
# 6            DepDelay      0.1264
# 0               Month      0.0030
# 7            Distance      0.0019
# 3          CRSDepTime      0.0001
# 4             ArrTime      0.0000
# 5           FlightNum      0.0000
# 1          DayofMonth      0.0000
# 10          Cancelled      0.0000
# 11           Diverted      0.0000
# 2           DayOfWeek      0.0000

# %% [markdown]
# ### DecisionTree regression

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=1)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the predictions
predictions['DecisionTree'] = y_pred

# Save the metrics
metrics['DecisionTree'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['DecisionTree'] = abs(regr.feature_importances_)

# %%
# View the predictions
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Out:
#           Actual  Predicted
# 595091    9.0000     8.0000
# 699277   -3.0000     7.0000
# 513280   13.0000     8.0000
# 555111   11.0000     8.0000
# 1269142  19.0000    19.0000
# ...          ...        ...
# 1417777  23.0000    23.0000
# 67042    59.0000    59.0000
# 1311116  32.0000    32.0000
# 573072  134.0000   135.0000
# 740252    5.0000   -15.0000
#
# [581028 rows x 2 columns]

# %%
# Performance metrics
print('Coefficient of determination:', r2_score(y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.98642338842905
# Mean Absolute Error: 2.959146547154354
# Mean Squared Error: 43.840315785125675
# Root Mean Squared Error: 6.621201989452193

# %%
# Plot test vs predicted y
plt.scatter(y_test, y_pred, color='black', alpha=0.5)
plt.plot([0, 2000], [0, 2000], color='blue');

# %%
# Feature importance
pd.DataFrame({'Feature': X.columns, 'Importance': abs(regr.feature_importances_)}).sort_values('Importance', ascending=False)
# Out:
#               Feature  Importance
# 6            DepDelay      0.8846
# 14           NASDelay      0.0719
# 9             TaxiOut      0.0127
# 11           Diverted      0.0076
# 16  LateAircraftDelay      0.0068
# 12       CarrierDelay      0.0060
# 13       WeatherDelay      0.0024
# 7            Distance      0.0014
# 10          Cancelled      0.0014
# 5           FlightNum      0.0010
# 4             ArrTime      0.0009
# 8              TaxiIn      0.0008
# 3          CRSDepTime      0.0007
# 1          DayofMonth      0.0006
# 0               Month      0.0005
# 2           DayOfWeek      0.0004
# 15      SecurityDelay      0.0001

# %% [markdown]
# # Exercici 2

# %% [markdown]
# Compara’ls en base al MSE i al R2.

# %%
predictions
# Out:
#           Actual   Linear    Ridge    Lasso  ElasticNet  DecisionTree
# 595091    9.0000   7.8372   7.8372   8.1030      8.0423        8.0000
# 699277   -3.0000   7.2816   7.2816   6.9787      7.1478        7.0000
# 513280   13.0000   7.6456   7.6457   7.9639      8.0502        8.0000
# 555111   11.0000   7.8773   7.8773   7.8861      7.8827        8.0000
# 1269142  19.0000  13.3803  13.3803  13.3573     13.2797       19.0000
# ...          ...      ...      ...      ...         ...           ...
# 1417777  23.0000  17.6895  17.6897  18.4663     18.4524       23.0000
# 67042    59.0000  58.1246  58.1246  56.3559     57.1595       59.0000
# 1311116  32.0000  28.1329  28.1329  28.0173     27.9762       32.0000
# 573072  134.0000 134.8619 134.8619 134.5330    134.5538      135.0000
# 740252    5.0000   6.9668   6.9667   6.5370      6.4578      -15.0000
#
# [581028 rows x 6 columns]

# %%
model
# Out:
#                    Linear   Ridge   Lasso  ElasticNet
# intercept         -5.5495 -5.5496 -5.8637     -6.0274
# Month             -0.0432 -0.0432 -0.0000     -0.0030
# DayofMonth        -0.0021 -0.0021 -0.0000     -0.0000
# DayOfWeek         -0.0175 -0.0175 -0.0000     -0.0000
# CRSDepTime         0.0003  0.0003  0.0001      0.0001
# ArrTime            0.0000  0.0000  0.0000      0.0000
# FlightNum         -0.0000 -0.0000 -0.0000     -0.0000
# DepDelay           0.0838  0.0838  0.1222      0.1264
# Distance          -0.0019 -0.0019 -0.0019     -0.0019
# TaxiIn             0.1281  0.1281  0.1138      0.1333
# TaxiOut            0.1080  0.1080  0.1308      0.1365
# Cancelled          8.9999  8.9794  0.0000      0.0000
# Diverted          11.6212 11.6186  0.0000      0.0000
# CarrierDelay       0.9456  0.9456  0.9050      0.9006
# WeatherDelay       0.9376  0.9376  0.8962      0.8918
# NASDelay           0.9465  0.9465  0.9123      0.9072
# SecurityDelay      1.0015  1.0015  0.5934      0.6529
# LateAircraftDelay  0.9454  0.9454  0.9047      0.9003

# %%
feature_importance['median'] = feature_importance.median(axis=1)
feature_importance = feature_importance.sort_values('median', ascending=False)
del feature_importance['median']
feature_importance.style.background_gradient()
# Out:
# <style type="text/css">
# #T_109d4_row0_col0, #T_109d4_row0_col1, #T_109d4_row0_col4, #T_109d4_row1_col0, #T_109d4_row1_col1, #T_109d4_row2_col0, #T_109d4_row2_col1, #T_109d4_row3_col0, #T_109d4_row3_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_109d4_row0_col2, #T_109d4_row0_col3, #T_109d4_row6_col4, #T_109d4_row8_col0, #T_109d4_row8_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_109d4_row1_col2, #T_109d4_row2_col2 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_109d4_row1_col3, #T_109d4_row2_col3 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_109d4_row1_col4, #T_109d4_row2_col4, #T_109d4_row6_col0, #T_109d4_row6_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_109d4_row3_col2, #T_109d4_row3_col3 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_109d4_row3_col4, #T_109d4_row4_col4, #T_109d4_row5_col4, #T_109d4_row8_col2, #T_109d4_row8_col3, #T_109d4_row9_col0, #T_109d4_row9_col1, #T_109d4_row9_col2, #T_109d4_row9_col3, #T_109d4_row9_col4, #T_109d4_row10_col0, #T_109d4_row10_col1, #T_109d4_row10_col2, #T_109d4_row10_col3, #T_109d4_row10_col4, #T_109d4_row11_col2, #T_109d4_row11_col3, #T_109d4_row11_col4, #T_109d4_row12_col0, #T_109d4_row12_col1, #T_109d4_row12_col2, #T_109d4_row12_col3, #T_109d4_row12_col4, #T_109d4_row13_col0, #T_109d4_row13_col1, #T_109d4_row13_col2, #T_109d4_row13_col3, #T_109d4_row13_col4, #T_109d4_row14_col0, #T_109d4_row14_col1, #T_109d4_row14_col2, #T_109d4_row14_col3, #T_109d4_row14_col4, #T_109d4_row15_col0, #T_109d4_row15_col1, #T_109d4_row15_col2, #T_109d4_row15_col3, #T_109d4_row15_col4, #T_109d4_row16_col0, #T_109d4_row16_col1, #T_109d4_row16_col2, #T_109d4_row16_col3, #T_109d4_row16_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_109d4_row4_col0, #T_109d4_row4_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_109d4_row4_col2 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_109d4_row4_col3 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_109d4_row5_col0, #T_109d4_row5_col1, #T_109d4_row7_col0, #T_109d4_row7_col1, #T_109d4_row8_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_109d4_row5_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_109d4_row5_col3, #T_109d4_row7_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_109d4_row6_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_109d4_row6_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_109d4_row7_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_109d4_row7_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_109d4_row11_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_109d4_row11_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_109d4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_109d4_level0_row0" class="row_heading level0 row0" >NASDelay</th>
#       <td id="T_109d4_row0_col0" class="data row0 col0" >0.946476</td>
#       <td id="T_109d4_row0_col1" class="data row0 col1" >0.946469</td>
#       <td id="T_109d4_row0_col2" class="data row0 col2" >0.912261</td>
#       <td id="T_109d4_row0_col3" class="data row0 col3" >0.907172</td>
#       <td id="T_109d4_row0_col4" class="data row0 col4" >0.071919</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row1" class="row_heading level0 row1" >CarrierDelay</th>
#       <td id="T_109d4_row1_col0" class="data row1 col0" >0.945588</td>
#       <td id="T_109d4_row1_col1" class="data row1 col1" >0.945580</td>
#       <td id="T_109d4_row1_col2" class="data row1 col2" >0.904957</td>
#       <td id="T_109d4_row1_col3" class="data row1 col3" >0.900630</td>
#       <td id="T_109d4_row1_col4" class="data row1 col4" >0.006035</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row2" class="row_heading level0 row2" >LateAircraftDelay</th>
#       <td id="T_109d4_row2_col0" class="data row2 col0" >0.945363</td>
#       <td id="T_109d4_row2_col1" class="data row2 col1" >0.945355</td>
#       <td id="T_109d4_row2_col2" class="data row2 col2" >0.904735</td>
#       <td id="T_109d4_row2_col3" class="data row2 col3" >0.900341</td>
#       <td id="T_109d4_row2_col4" class="data row2 col4" >0.006817</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row3" class="row_heading level0 row3" >WeatherDelay</th>
#       <td id="T_109d4_row3_col0" class="data row3 col0" >0.937562</td>
#       <td id="T_109d4_row3_col1" class="data row3 col1" >0.937554</td>
#       <td id="T_109d4_row3_col2" class="data row3 col2" >0.896151</td>
#       <td id="T_109d4_row3_col3" class="data row3 col3" >0.891788</td>
#       <td id="T_109d4_row3_col4" class="data row3 col4" >0.002442</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row4" class="row_heading level0 row4" >SecurityDelay</th>
#       <td id="T_109d4_row4_col0" class="data row4 col0" >1.001459</td>
#       <td id="T_109d4_row4_col1" class="data row4 col1" >1.001451</td>
#       <td id="T_109d4_row4_col2" class="data row4 col2" >0.593381</td>
#       <td id="T_109d4_row4_col3" class="data row4 col3" >0.652913</td>
#       <td id="T_109d4_row4_col4" class="data row4 col4" >0.000126</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row5" class="row_heading level0 row5" >TaxiIn</th>
#       <td id="T_109d4_row5_col0" class="data row5 col0" >0.128058</td>
#       <td id="T_109d4_row5_col1" class="data row5 col1" >0.128063</td>
#       <td id="T_109d4_row5_col2" class="data row5 col2" >0.113774</td>
#       <td id="T_109d4_row5_col3" class="data row5 col3" >0.133278</td>
#       <td id="T_109d4_row5_col4" class="data row5 col4" >0.000843</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row6" class="row_heading level0 row6" >DepDelay</th>
#       <td id="T_109d4_row6_col0" class="data row6 col0" >0.083764</td>
#       <td id="T_109d4_row6_col1" class="data row6 col1" >0.083772</td>
#       <td id="T_109d4_row6_col2" class="data row6 col2" >0.122198</td>
#       <td id="T_109d4_row6_col3" class="data row6 col3" >0.126422</td>
#       <td id="T_109d4_row6_col4" class="data row6 col4" >0.884583</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row7" class="row_heading level0 row7" >TaxiOut</th>
#       <td id="T_109d4_row7_col0" class="data row7 col0" >0.107971</td>
#       <td id="T_109d4_row7_col1" class="data row7 col1" >0.107977</td>
#       <td id="T_109d4_row7_col2" class="data row7 col2" >0.130827</td>
#       <td id="T_109d4_row7_col3" class="data row7 col3" >0.136489</td>
#       <td id="T_109d4_row7_col4" class="data row7 col4" >0.012728</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row8" class="row_heading level0 row8" >Diverted</th>
#       <td id="T_109d4_row8_col0" class="data row8 col0" >11.621208</td>
#       <td id="T_109d4_row8_col1" class="data row8 col1" >11.618616</td>
#       <td id="T_109d4_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_109d4_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_109d4_row8_col4" class="data row8 col4" >0.007574</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row9" class="row_heading level0 row9" >Month</th>
#       <td id="T_109d4_row9_col0" class="data row9 col0" >0.043168</td>
#       <td id="T_109d4_row9_col1" class="data row9 col1" >0.043165</td>
#       <td id="T_109d4_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_109d4_row9_col3" class="data row9 col3" >0.003038</td>
#       <td id="T_109d4_row9_col4" class="data row9 col4" >0.000473</td>
#     </tr>
#     <tr>
#       <th id="T_109d4_level0_row10" class="row_heading level0 row10" >Distance</th>
#       <td id="T_109d4_row10_col0" class="data row10 col0" >0.001867</td>
#       <td id="T_109d4_row10_col1" class="data row10 col1" >0.001867</td>
#       <td id="T_109d4_row10_col2" class="data row10 col2" >0.00189

# %% [markdown]
# ### Performance

# %%
def highlight_max(s, props=''):
    return np.where(s == np.max(s.values), props, '')

# %%
def highlight_min(s, props=''):
    return np.where(s == np.min(s.values), props, '')

# %%
# Highlight in yellow the best method per metric 
idx = pd.IndexSlice
metrics.style.apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
             .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])
# Out:
# <style type="text/css">
# #T_62708_row0_col0, #T_62708_row1_col4, #T_62708_row2_col0, #T_62708_row3_col0 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_62708_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62708_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_62708_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_62708_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_62708_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_62708_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_62708_row0_col4" class="data row0 col4" >0.986423</td>
#     </tr>
#     <tr>
#       <th id="T_62708_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_62708_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_62708_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_62708_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_62708_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_62708_row1_col4" class="data row1 col4" >2.959147</td>
#     </tr>
#     <tr>
#       <th id="T_62708_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_62708_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_62708_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_62708_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_62708_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_62708_row2_col4" class="data row2 col4" >43.840316</td>
#     </tr>
#     <tr>
#       <th id="T_62708_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_62708_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_62708_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_62708_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_62708_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_62708_row3_col4" class="data row3 col4" >6.621202</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Exercici 3

# %% [markdown]
# Entrena’ls utilitzant els diferents paràmetres que admeten.

# %%
# Get the independent variable set
X = df[features]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %% [markdown]
# ### Linear regression with non-default parameters

# %%
# Create the linear regressor
regr = LinearRegression(fit_intercept=False)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_PARAM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### Ridge regression with non-default parameters

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0, fit_intercept=False)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_PARAM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### Lasso regression with non-default parameters

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0, fit_intercept=False)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_PARAM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### ElasticNet regression with non-default parameters

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0, fit_intercept=False)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_PARAM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Highlight in yellow the best method per metric
# and in green the best method with the non-default parameters
metrics[[col for col in metrics.columns if '_PARAM' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_PARAM':'ElasticNet_PARAM']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_PARAM':'ElasticNet_PARAM']])
# Out:
# <style type="text/css">
# #T_a8638_row0_col0, #T_a8638_row1_col4, #T_a8638_row2_col0, #T_a8638_row3_col0 {
#   background-color: #ffffb3;
# }
# #T_a8638_row0_col5, #T_a8638_row1_col6, #T_a8638_row2_col5, #T_a8638_row3_col5 {
#   background-color: #99ff66;
# }
# </style>
# <table id="T_a8638_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_PARAM</th>
#       <th class="col_heading level0 col6" >Ridge_PARAM</th>
#       <th class="col_heading level0 col7" >Lasso_PARAM</th>
#       <th class="col_heading level0 col8" >ElasticNet_PARAM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8638_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_a8638_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_a8638_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_a8638_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_a8638_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_a8638_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_a8638_row0_col5" class="data row0 col5" >0.989747</td>
#       <td id="T_a8638_row0_col6" class="data row0 col6" >0.989747</td>
#       <td id="T_a8638_row0_col7" class="data row0 col7" >0.989357</td>
#       <td id="T_a8638_row0_col8" class="data row0 col8" >0.989434</td>
#     </tr>
#     <tr>
#       <th id="T_a8638_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_a8638_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_a8638_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_a8638_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_a8638_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_a8638_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_a8638_row1_col5" class="data row1 col5" >3.982540</td>
#       <td id="T_a8638_row1_col6" class="data row1 col6" >3.982537</td>
#       <td id="T_a8638_row1_col7" class="data row1 col7" >4.015916</td>
#       <td id="T_a8638_row1_col8" class="data row1 col8" >4.009442</td>
#     </tr>
#     <tr>
#       <th id="T_a8638_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_a8638_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_a8638_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_a8638_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_a8638_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_a8638_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_a8638_row2_col5" class="data row2 col5" >33.106688</td>
#       <td id="T_a8638_row2_col6" class="data row2 col6" >33.106700</td>
#       <td id="T_a8638_row2_col7" class="data row2 col7" >34.367973</td>
#       <td id="T_a8638_row2_col8" class="data row2 col8" >34.119805</td>
#     </tr>
#     <tr>
#       <th id="T_a8638_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_a8638_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_a8638_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_a8638_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_a8638_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_a8638_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_a8638_row3_col5" class="data row3 col5" >5.753841</td>
#       <td id="T_a8638_row3_col6" class="data row3 col6" >5.753842</td>
#       <td id="T_a8638_row3_col7" class="data row3 col7" >5.862420</td>
#       <td id="T_a8638_row3_col8" class="data row3 col8" >5.841216</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### DecisionTree regression with non-default parameters

# %%
# Get a sample of the dataset
sample = df.sample(100000, random_state = 0)

X = sample[features]
y = sample[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
# Explore max_depth
mse_train = []
mse_test = []
max_depths = list(range(1, 60))
for max_depth in max_depths:
    regr = DecisionTreeRegressor(random_state=1, max_depth=max_depth)
    regr.fit(X_train, y_train)
    y_pred_train = regr.predict(X_train)
    y_pred = regr.predict(X_test)
    mse_train.append(mean_squared_error(y_train, y_pred_train))
    mse_test.append(mean_squared_error(y_test, y_pred))

line1, = plt.plot(max_depths, mse_train, 'blue', label='Train MSE')
line2, = plt.plot(max_depths, mse_test, 'red', label='Test MSE')
plt.ylabel('MSE score')
plt.xlabel('Max depth')
plt.legend();

# %%
# Explore min_samples_split
mse_train = []
mse_test = []
min_samples_splits = np.arange(0.1, 1, 0.1)
for min_samples_split in min_samples_splits:
    regr = DecisionTreeRegressor(random_state=1, min_samples_split=min_samples_split)
    regr.fit(X_train, y_train)
    y_pred_train = regr.predict(X_train)
    y_pred = regr.predict(X_test)
    mse_train.append(mean_squared_error(y_train, y_pred_train))
    mse_test.append(mean_squared_error(y_test, y_pred))

line1, = plt.plot(min_samples_splits, mse_train, 'blue', label='Train MSE')
line2, = plt.plot(min_samples_splits, mse_test, 'red', label='Test MSE')
plt.ylabel('MSE score')
plt.xlabel('Min sample split')
plt.legend();

# %%
# Explore min_samples_leaf
mse_train = []
mse_test = []
min_samples_leaves = np.arange(0.1, 0.6, 0.1)
for min_samples_leaf in min_samples_leaves:
    regr = DecisionTreeRegressor(random_state=1, min_samples_leaf=min_samples_leaf)
    regr.fit(X_train, y_train)
    y_pred_train = regr.predict(X_train)
    y_pred = regr.predict(X_test)
    mse_train.append(mean_squared_error(y_train, y_pred_train))
    mse_test.append(mean_squared_error(y_test, y_pred))

line1, = plt.plot(min_samples_leaves, mse_train, 'blue', label='Train MSE')
line2, = plt.plot(min_samples_leaves, mse_test, 'red', label='Test MSE')
plt.ylabel('MSE score')
plt.xlabel('Min samples leaf')
plt.legend();

# %%
# Explore max_features
mse_train = []
mse_test = []
max_features = np.arange(0.1, 1, 0.1)
for max_feature in max_features:
    regr = DecisionTreeRegressor(random_state=1, max_features=max_feature)
    regr.fit(X_train, y_train)
    y_pred_train = regr.predict(X_train)
    y_pred = regr.predict(X_test)
    mse_train.append(mean_squared_error(y_train, y_pred_train))
    mse_test.append(mean_squared_error(y_test, y_pred))

line1, = plt.plot(max_features, mse_train, 'blue', label='Train MSE')
line2, = plt.plot(max_features, mse_test, 'red', label='Test MSE')
plt.ylabel('MSE score')
plt.xlabel('Max features')
plt.legend();

# %% [markdown]
# # Exercici 4

# %% [markdown]
# Compara el seu rendiment utilitzant l’aproximació traint/test o utilitzant totes les dades (validació interna)

# %%
# Get the independent variable set
X = df[features]
y = df[target]

# %% [markdown]
# ### Linear regression CV

# %%
# Create the linear regressor
regr = LinearRegression()

# Train and make the predictions with CV
y_pred = cross_val_predict(regr, X, y, cv=10)

# Save the metrics
metrics['Linear_CV'] = [r2_score(y, y_pred), mean_absolute_error(y, y_pred), mean_squared_error(y, y_pred), np.sqrt(mean_squared_error(y, y_pred))]

# %% [markdown]
# ### Ridge regression CV

# %%
# Create the Ridge regressor
regr = Ridge(random_state=1)

# Train and make the predictions with CV
y_pred = cross_val_predict(regr, X, y, cv=10)

# Save the metrics
metrics['Ridge_CV'] = [r2_score(y, y_pred), mean_absolute_error(y, y_pred), mean_squared_error(y, y_pred), np.sqrt(mean_squared_error(y, y_pred))]

# %% [markdown]
# ### Lasso regression CV

# %%
# Create the Lasso regressor
regr = Lasso(random_state=1)

# Train and make the predictions with CV
y_pred = cross_val_predict(regr, X, y, cv=10)

# Save the metrics
metrics['Lasso_CV'] = [r2_score(y, y_pred), mean_absolute_error(y, y_pred), mean_squared_error(y, y_pred), np.sqrt(mean_squared_error(y, y_pred))]

# %% [markdown]
# ### ElasticNet regression CV

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=1)

# Train and make the predictions with CV
y_pred = cross_val_predict(regr, X, y, cv=10)

# Save the metrics
metrics['ElasticNet_CV'] = [r2_score(y, y_pred), mean_absolute_error(y, y_pred), mean_squared_error(y, y_pred), np.sqrt(mean_squared_error(y, y_pred))]

# %% [markdown]
# ### DecisionTree regression CV

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=1)

# Train and make the predictions with CV
y_pred = cross_val_predict(regr, X, y, cv=10)

# Save the metrics
metrics['DecisionTree_CV'] = [r2_score(y, y_pred), mean_absolute_error(y, y_pred), mean_squared_error(y, y_pred), np.sqrt(mean_squared_error(y, y_pred))]

# %% [markdown]
# ### Performance

# %%
# Highlight in yellow the best method per metric
# and in green the best method cross validated
metrics[[col for col in metrics.columns if '_CV' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_CV':'DecisionTree_CV']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_CV':'DecisionTree_CV']])
# Out:
# <style type="text/css">
# #T_1afaf_row0_col0, #T_1afaf_row2_col0, #T_1afaf_row3_col0 {
#   background-color: #ffffb3;
# }
# #T_1afaf_row0_col6, #T_1afaf_row2_col6, #T_1afaf_row3_col6 {
#   background-color: #99ff66;
# }
# #T_1afaf_row1_col9 {
#   background-color: #ffffb3;
#   background-color: #99ff66;
# }
# </style>
# <table id="T_1afaf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_CV</th>
#       <th class="col_heading level0 col6" >Ridge_CV</th>
#       <th class="col_heading level0 col7" >Lasso_CV</th>
#       <th class="col_heading level0 col8" >ElasticNet_CV</th>
#       <th class="col_heading level0 col9" >DecisionTree_CV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1afaf_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_1afaf_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_1afaf_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_1afaf_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_1afaf_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_1afaf_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_1afaf_row0_col5" class="data row0 col5" >0.989950</td>
#       <td id="T_1afaf_row0_col6" class="data row0 col6" >0.989950</td>
#       <td id="T_1afaf_row0_col7" class="data row0 col7" >0.989644</td>
#       <td id="T_1afaf_row0_col8" class="data row0 col8" >0.989679</td>
#       <td id="T_1afaf_row0_col9" class="data row0 col9" >0.986363</td>
#     </tr>
#     <tr>
#       <th id="T_1afaf_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_1afaf_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_1afaf_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_1afaf_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_1afaf_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_1afaf_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_1afaf_row1_col5" class="data row1 col5" >3.996558</td>
#       <td id="T_1afaf_row1_col6" class="data row1 col6" >3.996557</td>
#       <td id="T_1afaf_row1_col7" class="data row1 col7" >4.018884</td>
#       <td id="T_1afaf_row1_col8" class="data row1 col8" >4.023679</td>
#       <td id="T_1afaf_row1_col9" class="data row1 col9" >2.958501</td>
#     </tr>
#     <tr>
#       <th id="T_1afaf_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_1afaf_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_1afaf_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_1afaf_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_1afaf_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_1afaf_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_1afaf_row2_col5" class="data row2 col5" >32.281162</td>
#       <td id="T_1afaf_row2_col6" class="data row2 col6" >32.281122</td>
#       <td id="T_1afaf_row2_col7" class="data row2 col7" >33.263150</td>
#       <td id="T_1afaf_row2_col8" class="data row2 col8" >33.150679</td>
#       <td id="T_1afaf_row2_col9" class="data row2 col9" >43.802843</td>
#     </tr>
#     <tr>
#       <th id="T_1afaf_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_1afaf_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_1afaf_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_1afaf_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_1afaf_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_1afaf_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_1afaf_row3_col5" class="data row3 col5" >5.681651</td>
#       <td id="T_1afaf_row3_col6" class="data row3 col6" >5.681648</td>
#       <td id="T_1afaf_row3_col7" class="data row3 col7" >5.767421</td>
#       <td id="T_1afaf_row3_col8" class="data row3 col8" >5.757663</td>
#       <td id="T_1afaf_row3_col9" class="data row3 col9" >6.618372</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Exercici 5

# %% [markdown]
# Realitza algun procés d’enginyeria de variables per millorar-ne la predicció

# %% [markdown]
# ### Categorical features

# %%
# Select categorical features
features_cat = df.select_dtypes(exclude=np.number).columns.tolist()
features_cat_cod = [col + '_cod' for col in features_cat]

# Join numerical and categorical features
features_all = features + features_cat_cod

# %%
# Check missing values
df[features_cat].isnull().sum()
# Out:
# UniqueCarrier       0
# TailNum             5
# Origin              0
# Dest                0
# CancellationCode    0
# dtype: int64

# %%
# Fill the missing values of TailNum with the most common category
df['TailNum'].fillna(df.TailNum.mode().squeeze(), inplace=True)

# %%
# Encode the categorical features
encoder = LabelEncoder()
for col in features_cat:
    df[col + '_cod']= encoder.fit_transform(df[col])

# %%
# Get the independent variable set
X = df[features_all]

# %%
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#                  feature     VIF
# 21  CancellationCode_cod 50.6763
# 9               DepDelay 35.7114
# 14            CRSDepTime 16.0665
# 7      LateAircraftDelay 13.8197
# 13          CarrierDelay 12.5887
# 6                ArrTime 11.6651
# 5               NASDelay  6.9198
# 12               TaxiOut  5.2739
# 17     UniqueCarrier_cod  5.0848
# 2              DayOfWeek  4.9935
# 20              Dest_cod  4.6135
# 19            Origin_cod  4.5092
# 18           TailNum_cod  4.2617
# 8             DayofMonth  4.2389
# 16                 Month  4.1062
# 1               Distance  3.3984
# 3           WeatherDelay  3.3149
# 15                TaxiIn  3.2085
# 10             FlightNum  2.6843
# 4               Diverted  1.0951
# 0              Cancelled  1.0311
# 11         SecurityDelay  1.0220

# %%
# Remove the feature with the highest VIF
del X['CancellationCode_cod']

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# Calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show VIF values
vif_data.sort_values('VIF', ascending=False)
# Out:
#               feature     VIF
# 9            DepDelay 34.9282
# 14         CRSDepTime 14.0023
# 7   LateAircraftDelay 13.5744
# 13       CarrierDelay 12.4175
# 6             ArrTime 11.0212
# 5            NASDelay  6.7254
# 12            TaxiOut  4.9379
# 2           DayOfWeek  4.6613
# 17  UniqueCarrier_cod  4.6604
# 20           Dest_cod  4.2783
# 19         Origin_cod  4.2053
# 8          DayofMonth  4.0041
# 18        TailNum_cod  3.9347
# 16              Month  3.8885
# 3        WeatherDelay  3.2639
# 1            Distance  3.1791
# 15             TaxiIn  2.9986
# 10          FlightNum  2.5738
# 4            Diverted  1.0934
# 11      SecurityDelay  1.0219
# 0           Cancelled  1.0167

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
for col in X.columns:
    if col.endswith('_cod'):
        row = pd.Series({col: np.nan for col in feature_importance.columns}, name=col)
        feature_importance = feature_importance.append(row)

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_CAT'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Linear_CAT'] = abs(regr.coef_)

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_CAT'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Ridge_CAT'] = abs(regr.coef_)

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_CAT'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['Lasso_CAT'] = abs(regr.coef_)

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_CAT'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['ElasticNet_CAT'] = abs(regr.coef_)

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_CAT'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# Save the feature importance
feature_importance['DecisionTree_CAT'] = abs(regr.feature_importances_)

# %%
feature_importance['median'] = feature_importance.median(axis=1)
feature_importance = feature_importance.sort_values('median', ascending=False)
del feature_importance['median']
feature_importance.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d1104_row0_col0, #T_d1104_row0_col1, #T_d1104_row0_col4, #T_d1104_row1_col0, #T_d1104_row1_col1, #T_d1104_row1_col5, #T_d1104_row1_col6, #T_d1104_row4_col5, #T_d1104_row4_col6, #T_d1104_row5_col5, #T_d1104_row5_col6, #T_d1104_row5_col9, #T_d1104_row8_col0, #T_d1104_row8_col1, #T_d1104_row9_col5, #T_d1104_row9_col6, #T_d1104_row11_col0, #T_d1104_row11_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d1104_row0_col2, #T_d1104_row0_col3, #T_d1104_row3_col5, #T_d1104_row3_col6, #T_d1104_row5_col7, #T_d1104_row5_col8, #T_d1104_row6_col9, #T_d1104_row7_col4, #T_d1104_row12_col0, #T_d1104_row12_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d1104_row0_col5, #T_d1104_row2_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_d1104_row0_col6, #T_d1104_row2_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_d1104_row0_col7, #T_d1104_row0_col8, #T_d1104_row0_col9, #T_d1104_row1_col4, #T_d1104_row1_col9, #T_d1104_row2_col2, #T_d1104_row2_col3, #T_d1104_row2_col4, #T_d1104_row2_col9, #T_d1104_row3_col4, #T_d1104_row3_col7, #T_d1104_row3_col8, #T_d1104_row5_col4, #T_d1104_row6_col0, #T_d1104_row6_col1, #T_d1104_row6_col2, #T_d1104_row6_col3, #T_d1104_row6_col4, #T_d1104_row7_col5, #T_d1104_row7_col6, #T_d1104_row7_col7, #T_d1104_row7_col8, #T_d1104_row7_col9, #T_d1104_row8_col5, #T_d1104_row8_col6, #T_d1104_row8_col7, #T_d1104_row8_col8, #T_d1104_row8_col9, #T_d1104_row9_col0, #T_d1104_row9_col1, #T_d1104_row9_col2, #T_d1104_row9_col3, #T_d1104_row9_col4, #T_d1104_row10_col0, #T_d1104_row10_col1, #T_d1104_row10_col2, #T_d1104_row10_col3, #T_d1104_row10_col4, #T_d1104_row11_col5, #T_d1104_row11_col6, #T_d1104_row11_col7, #T_d1104_row11_col8, #T_d1104_row11_col9, #T_d1104_row12_col2, #T_d1104_row12_col3, #T_d1104_row12_col5, #T_d1104_row12_col6, #T_d1104_row12_col7, #T_d1104_row12_col8, #T_d1104_row12_col9, #T_d1104_row13_col5, #T_d1104_row13_col6, #T_d1104_row13_col7, #T_d1104_row13_col8, #T_d1104_row13_col9, #T_d1104_row14_col0, #T_d1104_row14_col1, #T_d1104_row14_col2, #T_d1104_row14_col3, #T_d1104_row14_col4, #T_d1104_row14_col5, #T_d1104_row14_col6, #T_d1104_row14_col7, #T_d1104_row14_col8, #T_d1104_row14_col9, #T_d1104_row15_col0, #T_d1104_row15_col1, #T_d1104_row15_col2, #T_d1104_row15_col3, #T_d1104_row15_col4, #T_d1104_row15_col9, #T_d1104_row16_col5, #T_d1104_row16_col6, #T_d1104_row16_col7, #T_d1104_row16_col8, #T_d1104_row16_col9, #T_d1104_row17_col5, #T_d1104_row17_col6, #T_d1104_row17_col7, #T_d1104_row17_col8, #T_d1104_row17_col9, #T_d1104_row18_col0, #T_d1104_row18_col1, #T_d1104_row18_col2, #T_d1104_row18_col3, #T_d1104_row18_col4, #T_d1104_row18_col5, #T_d1104_row18_col6, #T_d1104_row18_col7, #T_d1104_row18_col8, #T_d1104_row18_col9, #T_d1104_row19_col0, #T_d1104_row19_col1, #T_d1104_row19_col2, #T_d1104_row19_col3, #T_d1104_row19_col4, #T_d1104_row19_col5, #T_d1104_row19_col6, #T_d1104_row19_col7, #T_d1104_row19_col8, #T_d1104_row19_col9, #T_d1104_row20_col5, #T_d1104_row20_col6, #T_d1104_row20_col7, #T_d1104_row20_col8, #T_d1104_row20_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d1104_row1_col2, #T_d1104_row1_col3, #T_d1104_row1_col7, #T_d1104_row1_col8 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_d1104_row2_col5, #T_d1104_row2_col6, #T_d1104_row3_col0, #T_d1104_row3_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d1104_row2_col7, #T_d1104_row3_col2 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_d1104_row2_col8, #T_d1104_row3_col3 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_d1104_row3_col9, #T_d1104_row4_col0, #T_d1104_row4_col1, #T_d1104_row5_col0, #T_d1104_row5_col1, #T_d1104_row10_col5, #T_d1104_row10_col6, #T_d1104_row12_col4, #T_d1104_row15_col5, #T_d1104_row15_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d1104_row4_col2, #T_d1104_row10_col7 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d1104_row4_col3, #T_d1104_row5_col3, #T_d1104_row10_col8, #T_d1104_row15_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d1104_row4_col4, #T_d1104_row10_col9 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d1104_row4_col7, #T_d1104_row8_col2, #T_d1104_row11_col2 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_d1104_row4_col8, #T_d1104_row8_col3, #T_d1104_row9_col7, #T_d1104_row9_col8, #T_d1104_row11_col3 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_d1104_row4_col9, #T_d1104_row6_col5, #T_d1104_row6_col6, #T_d1104_row7_col0, #T_d1104_row7_col1, #T_d1104_row8_col4, #T_d1104_row9_col9, #T_d1104_row11_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d1104_row5_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d1104_row6_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d1104_row6_col8, #T_d1104_row7_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_d1104_row7_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d1104_row13_col0, #T_d1104_row13_col1, #T_d1104_row13_col2, #T_d1104_row13_col3, #T_d1104_row13_col4, #T_d1104_row16_col0, #T_d1104_row16_col1, #T_d1104_row16_col2, #T_d1104_row16_col3, #T_d1104_row16_col4, #T_d1104_row17_col0, #T_d1104_row17_col1, #T_d1104_row17_col2, #T_d1104_row17_col3, #T_d1104_row17_col4, #T_d1104_row20_col0, #T_d1104_row20_col1, #T_d1104_row20_col2, #T_d1104_row20_col3, #T_d1104_row20_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d1104_row15_col7 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# </style>
# <table id="T_d1104_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_CAT</th>
#       <th class="col_heading level0 col6" >Ridge_CAT</th>
#       <th class="col_heading level0 col7" >Lasso_CAT</th>
#       <th class="col_heading level0 col8" >ElasticNet_CAT</th>
#       <th class="col_heading level0 col9" >DecisionTree_CAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1104_level0_row0" class="row_heading level0 row0" >NASDelay</th>
#       <td id="T_d1104_row0_col0" class="data row0 col0" >0.946476</td>
#       <td id="T_d1104_row0_col1" class="data row0 col1" >0.946469</td>
#       <td id="T_d1104_row0_col2" class="data row0 col2" >0.912261</td>
#       <td id="T_d1104_row0_col3" class="data row0 col3" >0.907172</td>
#       <td id="T_d1104_row0_col4" class="data row0 col4" >0.071919</td>
#       <td id="T_d1104_row0_col5" class="data row0 col5" >8.990366</td>
#       <td id="T_d1104_row0_col6" class="data row0 col6" >8.969922</td>
#       <td id="T_d1104_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_d1104_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_d1104_row0_col9" class="data row0 col9" >0.001428</td>
#     </tr>
#     <tr>
#       <th id="T_d1104_level0_row1" class="row_heading level0 row1" >WeatherDelay</th>
#       <td id="T_d1104_row1_col0" class="data row1 col0" >0.937562</td>
#       <td id="T_d1104_row1_col1" class="data row1 col1" >0.937554</td>
#       <td id="T_d1104_row1_col2" class="data row1 col2" >0.896151</td>
#       <td id="T_d1104_row1_col3" class="data row1 col3" >0.891788</td>
#       <td id="T_d1104_row1_col4" class="data row1 col4" >0.002442</td>
#       <td id="T_d1104_row1_col5" class="data row1 col5" >0.937345</td>
#       <td id="T_d1104_row1_col6" class="data row1 col6" >0.937337</td>
#       <td id="T_d1104_row1_col7" class="data row1 col7" >0.897240</td>
#       <td id="T_d1104_row1_col8" class="data row1 col8" >0.892933</td>
#       <td id="T_d1104_row1_col9" class="data row1 col9" >0.002434</td>
#     </tr>
#     <tr>
#       <th id="T_d1104_level0_row2" class="row_heading level0 row2" >Cancelled</th>
#       <td id="T_d1104_row2_col0" class="data row2 col0" >8.999874</td>
#       <td id="T_d1104_row2_col1" class="data row2 col1" >8.979412<

# %%
# Highlight in yellow the best method per metric 
# and in green the best method with categorical features
metrics[[col for col in metrics.columns if '_CAT' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_CAT':'DecisionTree_CAT']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_CAT':'DecisionTree_CAT']])
# Out:
# <style type="text/css">
# #T_7823c_row0_col5, #T_7823c_row1_col9, #T_7823c_row2_col5, #T_7823c_row3_col5 {
#   background-color: #ffffb3;
#   background-color: #99ff66;
# }
# </style>
# <table id="T_7823c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_CAT</th>
#       <th class="col_heading level0 col6" >Ridge_CAT</th>
#       <th class="col_heading level0 col7" >Lasso_CAT</th>
#       <th class="col_heading level0 col8" >ElasticNet_CAT</th>
#       <th class="col_heading level0 col9" >DecisionTree_CAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7823c_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_7823c_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_7823c_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_7823c_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_7823c_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_7823c_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_7823c_row0_col5" class="data row0 col5" >0.990017</td>
#       <td id="T_7823c_row0_col6" class="data row0 col6" >0.990017</td>
#       <td id="T_7823c_row0_col7" class="data row0 col7" >0.989702</td>
#       <td id="T_7823c_row0_col8" class="data row0 col8" >0.989736</td>
#       <td id="T_7823c_row0_col9" class="data row0 col9" >0.987019</td>
#     </tr>
#     <tr>
#       <th id="T_7823c_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_7823c_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_7823c_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_7823c_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_7823c_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_7823c_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_7823c_row1_col5" class="data row1 col5" >3.985707</td>
#       <td id="T_7823c_row1_col6" class="data row1 col6" >3.985705</td>
#       <td id="T_7823c_row1_col7" class="data row1 col7" >4.014436</td>
#       <td id="T_7823c_row1_col8" class="data row1 col8" >4.012806</td>
#       <td id="T_7823c_row1_col9" class="data row1 col9" >2.876935</td>
#     </tr>
#     <tr>
#       <th id="T_7823c_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_7823c_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_7823c_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_7823c_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_7823c_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_7823c_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_7823c_row2_col5" class="data row2 col5" >32.237444</td>
#       <td id="T_7823c_row2_col6" class="data row2 col6" >32.237459</td>
#       <td id="T_7823c_row2_col7" class="data row2 col7" >33.254461</td>
#       <td id="T_7823c_row2_col8" class="data row2 col8" >33.142908</td>
#       <td id="T_7823c_row2_col9" class="data row2 col9" >41.917291</td>
#     </tr>
#     <tr>
#       <th id="T_7823c_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_7823c_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_7823c_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_7823c_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_7823c_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_7823c_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_7823c_row3_col5" class="data row3 col5" >5.677803</td>
#       <td id="T_7823c_row3_col6" class="data row3 col6" >5.677804</td>
#       <td id="T_7823c_row3_col7" class="data row3 col7" >5.766668</td>
#       <td id="T_7823c_row3_col8" class="data row3 col8" >5.756988</td>
#       <td id="T_7823c_row3_col9" class="data row3 col9" >6.474356</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Feature transformation: standaritzation

# %%
# Get the independent variable set
X = df[features]

# Standarize features according to its mean and variance
X = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_STD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_STD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_STD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_STD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_STD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Highlight in yellow the best method per metric 
# and in green the best method with standarized features
metrics[[col for col in metrics.columns if '_STD' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_STD':'DecisionTree_STD']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_STD':'DecisionTree_STD']])
# Out:
# <style type="text/css">
# #T_cde27_row0_col5, #T_cde27_row1_col9, #T_cde27_row2_col5, #T_cde27_row3_col5 {
#   background-color: #ffffb3;
#   background-color: #99ff66;
# }
# </style>
# <table id="T_cde27_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_STD</th>
#       <th class="col_heading level0 col6" >Ridge_STD</th>
#       <th class="col_heading level0 col7" >Lasso_STD</th>
#       <th class="col_heading level0 col8" >ElasticNet_STD</th>
#       <th class="col_heading level0 col9" >DecisionTree_STD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cde27_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_cde27_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_cde27_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_cde27_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_cde27_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_cde27_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_cde27_row0_col5" class="data row0 col5" >0.990010</td>
#       <td id="T_cde27_row0_col6" class="data row0 col6" >0.990010</td>
#       <td id="T_cde27_row0_col7" class="data row0 col7" >0.982455</td>
#       <td id="T_cde27_row0_col8" class="data row0 col8" >0.931018</td>
#       <td id="T_cde27_row0_col9" class="data row0 col9" >0.986533</td>
#     </tr>
#     <tr>
#       <th id="T_cde27_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_cde27_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_cde27_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_cde27_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_cde27_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_cde27_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_cde27_row1_col5" class="data row1 col5" >3.988308</td>
#       <td id="T_cde27_row1_col6" class="data row1 col6" >3.988304</td>
#       <td id="T_cde27_row1_col7" class="data row1 col7" >5.241195</td>
#       <td id="T_cde27_row1_col8" class="data row1 col8" >10.076003</td>
#       <td id="T_cde27_row1_col9" class="data row1 col9" >2.956367</td>
#     </tr>
#     <tr>
#       <th id="T_cde27_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_cde27_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_cde27_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_cde27_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_cde27_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_cde27_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_cde27_row2_col5" class="data row2 col5" >32.259567</td>
#       <td id="T_cde27_row2_col6" class="data row2 col6" >32.259577</td>
#       <td id="T_cde27_row2_col7" class="data row2 col7" >56.654741</td>
#       <td id="T_cde27_row2_col8" class="data row2 col8" >222.750518</td>
#       <td id="T_cde27_row2_col9" class="data row2 col9" >43.484817</td>
#     </tr>
#     <tr>
#       <th id="T_cde27_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_cde27_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_cde27_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_cde27_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_cde27_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_cde27_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_cde27_row3_col5" class="data row3 col5" >5.679751</td>
#       <td id="T_cde27_row3_col6" class="data row3 col6" >5.679752</td>
#       <td id="T_cde27_row3_col7" class="data row3 col7" >7.526934</td>
#       <td id="T_cde27_row3_col8" class="data row3 col8" >14.924829</td>
#       <td id="T_cde27_row3_col9" class="data row3 col9" >6.594302</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Feature transformation: normalization

# %%
# Get the independent variable set
X = df[features]

# Standarize features according to its mean and variance
X = MinMaxScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_NORM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_NORM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_NORM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_NORM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_NORM'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Highlight in yellow the best method per metric 
# and in green the best method with normalized features
metrics[[col for col in metrics.columns if '_NORM' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_NORM':'DecisionTree_NORM']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_NORM':'DecisionTree_NORM']])
# Out:
# <style type="text/css">
# #T_81120_row0_col5, #T_81120_row1_col9, #T_81120_row2_col5, #T_81120_row3_col5 {
#   background-color: #ffffb3;
#   background-color: #99ff66;
# }
# </style>
# <table id="T_81120_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_NORM</th>
#       <th class="col_heading level0 col6" >Ridge_NORM</th>
#       <th class="col_heading level0 col7" >Lasso_NORM</th>
#       <th class="col_heading level0 col8" >ElasticNet_NORM</th>
#       <th class="col_heading level0 col9" >DecisionTree_NORM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81120_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_81120_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_81120_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_81120_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_81120_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_81120_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_81120_row0_col5" class="data row0 col5" >0.990010</td>
#       <td id="T_81120_row0_col6" class="data row0 col6" >0.989877</td>
#       <td id="T_81120_row0_col7" class="data row0 col7" >0.233343</td>
#       <td id="T_81120_row0_col8" class="data row0 col8" >0.001533</td>
#       <td id="T_81120_row0_col9" class="data row0 col9" >0.986527</td>
#     </tr>
#     <tr>
#       <th id="T_81120_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_81120_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_81120_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_81120_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_81120_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_81120_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_81120_row1_col5" class="data row1 col5" >3.988308</td>
#       <td id="T_81120_row1_col6" class="data row1 col6" >4.003947</td>
#       <td id="T_81120_row1_col7" class="data row1 col7" >32.776500</td>
#       <td id="T_81120_row1_col8" class="data row1 col8" >37.185624</td>
#       <td id="T_81120_row1_col9" class="data row1 col9" >2.956832</td>
#     </tr>
#     <tr>
#       <th id="T_81120_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_81120_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_81120_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_81120_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_81120_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_81120_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_81120_row2_col5" class="data row2 col5" >32.259567</td>
#       <td id="T_81120_row2_col6" class="data row2 col6" >32.688753</td>
#       <td id="T_81120_row2_col7" class="data row2 col7" >2475.615340</td>
#       <td id="T_81120_row2_col8" class="data row2 col8" >3224.155274</td>
#       <td id="T_81120_row2_col9" class="data row2 col9" >43.505432</td>
#     </tr>
#     <tr>
#       <th id="T_81120_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_81120_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_81120_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_81120_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_81120_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_81120_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_81120_row3_col5" class="data row3 col5" >5.679751</td>
#       <td id="T_81120_row3_col6" class="data row3 col6" >5.717408</td>
#       <td id="T_81120_row3_col7" class="data row3 col7" >49.755556</td>
#       <td id="T_81120_row3_col8" class="data row3 col8" >56.781646</td>
#       <td id="T_81120_row3_col9" class="data row3 col9" >6.595865</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Feature transformation: Gaussian distribution

# %%
# Get the independent variable set
X = df[features]

# Standarize features according to its mean and variance
X = PowerTransformer().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_GAU'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_GAU'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_GAU'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_GAU'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_GAU'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Highlight in yellow the best method per metric 
# and in green the best method with gaussian-like distributed features
metrics[[col for col in metrics.columns if '_GAU' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_GAU':'DecisionTree_GAU']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_GAU':'DecisionTree_GAU']])
# Out:
# <style type="text/css">
# #T_a6115_row0_col0, #T_a6115_row1_col4, #T_a6115_row2_col0, #T_a6115_row3_col0 {
#   background-color: #ffffb3;
# }
# #T_a6115_row0_col9, #T_a6115_row1_col9, #T_a6115_row2_col9, #T_a6115_row3_col9 {
#   background-color: #99ff66;
# }
# </style>
# <table id="T_a6115_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_GAU</th>
#       <th class="col_heading level0 col6" >Ridge_GAU</th>
#       <th class="col_heading level0 col7" >Lasso_GAU</th>
#       <th class="col_heading level0 col8" >ElasticNet_GAU</th>
#       <th class="col_heading level0 col9" >DecisionTree_GAU</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6115_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_a6115_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_a6115_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_a6115_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_a6115_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_a6115_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_a6115_row0_col5" class="data row0 col5" >0.623717</td>
#       <td id="T_a6115_row0_col6" class="data row0 col6" >0.623717</td>
#       <td id="T_a6115_row0_col7" class="data row0 col7" >0.618141</td>
#       <td id="T_a6115_row0_col8" class="data row0 col8" >0.544335</td>
#       <td id="T_a6115_row0_col9" class="data row0 col9" >0.985635</td>
#     </tr>
#     <tr>
#       <th id="T_a6115_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_a6115_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_a6115_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_a6115_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_a6115_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_a6115_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_a6115_row1_col5" class="data row1 col5" >20.917925</td>
#       <td id="T_a6115_row1_col6" class="data row1 col6" >20.917916</td>
#       <td id="T_a6115_row1_col7" class="data row1 col7" >20.812572</td>
#       <td id="T_a6115_row1_col8" class="data row1 col8" >20.321121</td>
#       <td id="T_a6115_row1_col9" class="data row1 col9" >3.059770</td>
#     </tr>
#     <tr>
#       <th id="T_a6115_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_a6115_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_a6115_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_a6115_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_a6115_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_a6115_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_a6115_row2_col5" class="data row2 col5" >1215.057801</td>
#       <td id="T_a6115_row2_col6" class="data row2 col6" >1215.057809</td>
#       <td id="T_a6115_row2_col7" class="data row2 col7" >1233.061604</td>
#       <td id="T_a6115_row2_col8" class="data row2 col8" >1471.390667</td>
#       <td id="T_a6115_row2_col9" class="data row2 col9" >46.387028</td>
#     </tr>
#     <tr>
#       <th id="T_a6115_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_a6115_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_a6115_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_a6115_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_a6115_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_a6115_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_a6115_row3_col5" class="data row3 col5" >34.857679</td>
#       <td id="T_a6115_row3_col6" class="data row3 col6" >34.857679</td>
#       <td id="T_a6115_row3_col7" class="data row3 col7" >35.114977</td>
#       <td id="T_a6115_row3_col8" class="data row3 col8" >38.358710</td>
#       <td id="T_a6115_row3_col9" class="data row3 col9" >6.810802</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Feature selection: PCA

# %%
# Get the independent variable set
X = df[features]

# Standarize features
X = StandardScaler().fit_transform(X)

# Principal Component Analysys
pca = PCA(n_components=0.9)
X = pca.fit_transform(X)
print(pca.explained_variance_ratio_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)
# Out:
# [0.11164453 0.08737531 0.08547173 0.07967156 0.06381367 0.06297319
#  0.0593401  0.0591998  0.0587685  0.0584257  0.05788764 0.05608647
#  0.05423756 0.03780488]

# %%
# Create the linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_PCA'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Ridge regressor
regr = Ridge(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_PCA'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the Lasso regressor
regr = Lasso(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_PCA'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the ElasticNet regressor
regr = ElasticNet(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_PCA'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor(random_state=0)

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_PCA'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %%
# Highlight in yellow the best method per metric 
# and in green the best method with gaussian-like distributed features
metrics[[col for col in metrics.columns if '_PCA' in col or not '_' in col]].style\
    .apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
    .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
    .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_PCA':'DecisionTree_PCA']])\
    .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_PCA':'DecisionTree_PCA']])
# Out:
# <style type="text/css">
# #T_3544b_row0_col0, #T_3544b_row1_col4, #T_3544b_row2_col0, #T_3544b_row3_col0 {
#   background-color: #ffffb3;
# }
# #T_3544b_row0_col6, #T_3544b_row1_col5, #T_3544b_row2_col6, #T_3544b_row3_col6 {
#   background-color: #99ff66;
# }
# </style>
# <table id="T_3544b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_PCA</th>
#       <th class="col_heading level0 col6" >Ridge_PCA</th>
#       <th class="col_heading level0 col7" >Lasso_PCA</th>
#       <th class="col_heading level0 col8" >ElasticNet_PCA</th>
#       <th class="col_heading level0 col9" >DecisionTree_PCA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3544b_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_3544b_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_3544b_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_3544b_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_3544b_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_3544b_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_3544b_row0_col5" class="data row0 col5" >0.976700</td>
#       <td id="T_3544b_row0_col6" class="data row0 col6" >0.976700</td>
#       <td id="T_3544b_row0_col7" class="data row0 col7" >0.973493</td>
#       <td id="T_3544b_row0_col8" class="data row0 col8" >0.928705</td>
#       <td id="T_3544b_row0_col9" class="data row0 col9" >0.963658</td>
#     </tr>
#     <tr>
#       <th id="T_3544b_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_3544b_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_3544b_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_3544b_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_3544b_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_3544b_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_3544b_row1_col5" class="data row1 col5" >6.102400</td>
#       <td id="T_3544b_row1_col6" class="data row1 col6" >6.102400</td>
#       <td id="T_3544b_row1_col7" class="data row1 col7" >6.601798</td>
#       <td id="T_3544b_row1_col8" class="data row1 col8" >10.292369</td>
#       <td id="T_3544b_row1_col9" class="data row1 col9" >7.949469</td>
#     </tr>
#     <tr>
#       <th id="T_3544b_level0_row2" class="row_heading level0 row2" >Mean Squared Error</th>
#       <td id="T_3544b_row2_col0" class="data row2 col0" >32.259567</td>
#       <td id="T_3544b_row2_col1" class="data row2 col1" >32.259582</td>
#       <td id="T_3544b_row2_col2" class="data row2 col2" >33.285517</td>
#       <td id="T_3544b_row2_col3" class="data row2 col3" >33.177898</td>
#       <td id="T_3544b_row2_col4" class="data row2 col4" >43.840316</td>
#       <td id="T_3544b_row2_col5" class="data row2 col5" >75.238925</td>
#       <td id="T_3544b_row2_col6" class="data row2 col6" >75.238923</td>
#       <td id="T_3544b_row2_col7" class="data row2 col7" >85.594301</td>
#       <td id="T_3544b_row2_col8" class="data row2 col8" >230.218586</td>
#       <td id="T_3544b_row2_col9" class="data row2 col9" >117.350985</td>
#     </tr>
#     <tr>
#       <th id="T_3544b_level0_row3" class="row_heading level0 row3" >Root Mean Squared Error</th>
#       <td id="T_3544b_row3_col0" class="data row3 col0" >5.679751</td>
#       <td id="T_3544b_row3_col1" class="data row3 col1" >5.679752</td>
#       <td id="T_3544b_row3_col2" class="data row3 col2" >5.769360</td>
#       <td id="T_3544b_row3_col3" class="data row3 col3" >5.760026</td>
#       <td id="T_3544b_row3_col4" class="data row3 col4" >6.621202</td>
#       <td id="T_3544b_row3_col5" class="data row3 col5" >8.674037</td>
#       <td id="T_3544b_row3_col6" class="data row3 col6" >8.674037</td>
#       <td id="T_3544b_row3_col7" class="data row3 col7" >9.251719</td>
#       <td id="T_3544b_row3_col8" class="data row3 col8" >15.172956</td>
#       <td id="T_3544b_row3_col9" class="data row3 col9" >10.832866</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Exercici 6

# %% [markdown]
# No utilitzis la variable DepDelay a l’hora de fer prediccions

# %%
X = df[features]

# Remove DepDelay and its sources
X = X.drop(['DepDelay', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %% [markdown]
# ### LinearRegression without DepDelay

# %%
# Create the Linear regressor
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Linear_DD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### Ridge regression without DepDelay

# %%
# Create the Ridge regressor
regr = Ridge()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Ridge_DD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### Lasso regression without DepDelay

# %%
# Create the Lasso regressor
regr = Lasso()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['Lasso_DD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### ElasticNet regression without DepDelay

# %%
# Create the linear regressor
regr = ElasticNet()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['ElasticNet_DD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### DecisionTree regression without DepDelay

# %%
# Create the DecisionTree regressor
regr = DecisionTreeRegressor()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# Save the metrics
metrics['DecisionTree_DD'] = [r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), mean_squared_error(y_test, y_pred), np.sqrt(mean_squared_error(y_test, y_pred))]

# %% [markdown]
# ### Performance

# %%
# Highlight in yellow the best method per metric 
# and in green the best method without DepDelay
metrics.style.apply(highlight_max, props='background-color:#ffffb3;', axis=1, subset=idx[idx['R2'], idx[:]])\
             .apply(highlight_min, props='background-color:#ffffb3;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx[:]])\
             .apply(highlight_max, props='background-color:#99ff66;', axis=1, subset=idx[idx['R2'], idx['Linear_DD':'DecisionTree_DD']])\
             .apply(highlight_min, props='background-color:#99ff66;', axis=1, subset=idx[idx['Mean Absolute Error':'Root Mean Squared Error'], idx['Linear_DD':'DecisionTree_DD']])
# Out:
# <style type="text/css">
# #T_cad44_row0_col14, #T_cad44_row1_col18, #T_cad44_row2_col14, #T_cad44_row3_col14 {
#   background-color: #ffffb3;
# }
# #T_cad44_row0_col43, #T_cad44_row1_col43, #T_cad44_row2_col43, #T_cad44_row3_col43 {
#   background-color: #99ff66;
# }
# </style>
# <table id="T_cad44_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linear</th>
#       <th class="col_heading level0 col1" >Ridge</th>
#       <th class="col_heading level0 col2" >Lasso</th>
#       <th class="col_heading level0 col3" >ElasticNet</th>
#       <th class="col_heading level0 col4" >DecisionTree</th>
#       <th class="col_heading level0 col5" >Linear_PARAM</th>
#       <th class="col_heading level0 col6" >Ridge_PARAM</th>
#       <th class="col_heading level0 col7" >Lasso_PARAM</th>
#       <th class="col_heading level0 col8" >ElasticNet_PARAM</th>
#       <th class="col_heading level0 col9" >Linear_CV</th>
#       <th class="col_heading level0 col10" >Ridge_CV</th>
#       <th class="col_heading level0 col11" >Lasso_CV</th>
#       <th class="col_heading level0 col12" >ElasticNet_CV</th>
#       <th class="col_heading level0 col13" >DecisionTree_CV</th>
#       <th class="col_heading level0 col14" >Linear_CAT</th>
#       <th class="col_heading level0 col15" >Ridge_CAT</th>
#       <th class="col_heading level0 col16" >Lasso_CAT</th>
#       <th class="col_heading level0 col17" >ElasticNet_CAT</th>
#       <th class="col_heading level0 col18" >DecisionTree_CAT</th>
#       <th class="col_heading level0 col19" >Linear_STD</th>
#       <th class="col_heading level0 col20" >Ridge_STD</th>
#       <th class="col_heading level0 col21" >Lasso_STD</th>
#       <th class="col_heading level0 col22" >ElasticNet_STD</th>
#       <th class="col_heading level0 col23" >DecisionTree_STD</th>
#       <th class="col_heading level0 col24" >Linear_NORM</th>
#       <th class="col_heading level0 col25" >Ridge_NORM</th>
#       <th class="col_heading level0 col26" >Lasso_NORM</th>
#       <th class="col_heading level0 col27" >ElasticNet_NORM</th>
#       <th class="col_heading level0 col28" >DecisionTree_NORM</th>
#       <th class="col_heading level0 col29" >Linear_GAU</th>
#       <th class="col_heading level0 col30" >Ridge_GAU</th>
#       <th class="col_heading level0 col31" >Lasso_GAU</th>
#       <th class="col_heading level0 col32" >ElasticNet_GAU</th>
#       <th class="col_heading level0 col33" >DecisionTree_GAU</th>
#       <th class="col_heading level0 col34" >Linear_PCA</th>
#       <th class="col_heading level0 col35" >Ridge_PCA</th>
#       <th class="col_heading level0 col36" >Lasso_PCA</th>
#       <th class="col_heading level0 col37" >ElasticNet_PCA</th>
#       <th class="col_heading level0 col38" >DecisionTree_PCA</th>
#       <th class="col_heading level0 col39" >Linear_DD</th>
#       <th class="col_heading level0 col40" >Ridge_DD</th>
#       <th class="col_heading level0 col41" >Lasso_DD</th>
#       <th class="col_heading level0 col42" >ElasticNet_DD</th>
#       <th class="col_heading level0 col43" >DecisionTree_DD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cad44_level0_row0" class="row_heading level0 row0" >R2</th>
#       <td id="T_cad44_row0_col0" class="data row0 col0" >0.990010</td>
#       <td id="T_cad44_row0_col1" class="data row0 col1" >0.990010</td>
#       <td id="T_cad44_row0_col2" class="data row0 col2" >0.989692</td>
#       <td id="T_cad44_row0_col3" class="data row0 col3" >0.989725</td>
#       <td id="T_cad44_row0_col4" class="data row0 col4" >0.986423</td>
#       <td id="T_cad44_row0_col5" class="data row0 col5" >0.989747</td>
#       <td id="T_cad44_row0_col6" class="data row0 col6" >0.989747</td>
#       <td id="T_cad44_row0_col7" class="data row0 col7" >0.989357</td>
#       <td id="T_cad44_row0_col8" class="data row0 col8" >0.989434</td>
#       <td id="T_cad44_row0_col9" class="data row0 col9" >0.989950</td>
#       <td id="T_cad44_row0_col10" class="data row0 col10" >0.989950</td>
#       <td id="T_cad44_row0_col11" class="data row0 col11" >0.989644</td>
#       <td id="T_cad44_row0_col12" class="data row0 col12" >0.989679</td>
#       <td id="T_cad44_row0_col13" class="data row0 col13" >0.986363</td>
#       <td id="T_cad44_row0_col14" class="data row0 col14" >0.990017</td>
#       <td id="T_cad44_row0_col15" class="data row0 col15" >0.990017</td>
#       <td id="T_cad44_row0_col16" class="data row0 col16" >0.989702</td>
#       <td id="T_cad44_row0_col17" class="data row0 col17" >0.989736</td>
#       <td id="T_cad44_row0_col18" class="data row0 col18" >0.987019</td>
#       <td id="T_cad44_row0_col19" class="data row0 col19" >0.990010</td>
#       <td id="T_cad44_row0_col20" class="data row0 col20" >0.990010</td>
#       <td id="T_cad44_row0_col21" class="data row0 col21" >0.982455</td>
#       <td id="T_cad44_row0_col22" class="data row0 col22" >0.931018</td>
#       <td id="T_cad44_row0_col23" class="data row0 col23" >0.986533</td>
#       <td id="T_cad44_row0_col24" class="data row0 col24" >0.990010</td>
#       <td id="T_cad44_row0_col25" class="data row0 col25" >0.989877</td>
#       <td id="T_cad44_row0_col26" class="data row0 col26" >0.233343</td>
#       <td id="T_cad44_row0_col27" class="data row0 col27" >0.001533</td>
#       <td id="T_cad44_row0_col28" class="data row0 col28" >0.986527</td>
#       <td id="T_cad44_row0_col29" class="data row0 col29" >0.623717</td>
#       <td id="T_cad44_row0_col30" class="data row0 col30" >0.623717</td>
#       <td id="T_cad44_row0_col31" class="data row0 col31" >0.618141</td>
#       <td id="T_cad44_row0_col32" class="data row0 col32" >0.544335</td>
#       <td id="T_cad44_row0_col33" class="data row0 col33" >0.985635</td>
#       <td id="T_cad44_row0_col34" class="data row0 col34" >0.976700</td>
#       <td id="T_cad44_row0_col35" class="data row0 col35" >0.976700</td>
#       <td id="T_cad44_row0_col36" class="data row0 col36" >0.973493</td>
#       <td id="T_cad44_row0_col37" class="data row0 col37" >0.928705</td>
#       <td id="T_cad44_row0_col38" class="data row0 col38" >0.963658</td>
#       <td id="T_cad44_row0_col39" class="data row0 col39" >0.113629</td>
#       <td id="T_cad44_row0_col40" class="data row0 col40" >0.113629</td>
#       <td id="T_cad44_row0_col41" class="data row0 col41" >0.113063</td>
#       <td id="T_cad44_row0_col42" class="data row0 col42" >0.113088</td>
#       <td id="T_cad44_row0_col43" class="data row0 col43" >0.677901</td>
#     </tr>
#     <tr>
#       <th id="T_cad44_level0_row1" class="row_heading level0 row1" >Mean Absolute Error</th>
#       <td id="T_cad44_row1_col0" class="data row1 col0" >3.988308</td>
#       <td id="T_cad44_row1_col1" class="data row1 col1" >3.988307</td>
#       <td id="T_cad44_row1_col2" class="data row1 col2" >4.017694</td>
#       <td id="T_cad44_row1_col3" class="data row1 col3" >4.016411</td>
#       <td id="T_cad44_row1_col4" class="data row1 col4" >2.959147</td>
#       <td id="T_cad44_row1_col5" class="data row1 col5" >3.982540</td>
#       <td id="T_cad44_row1_col6" class="data row1 col6" >3.982537</td>
#       <td id="T_cad44_row1_col7" class="data row1 col7" >4.015916</td>
#       <td id="T_cad44_row1_col8" class="data row1 col8" >4.009442</td>
#       <td id="T_cad44_row1_col9" class="data row1 col9" >3.996558</td>
#       <td id="T_cad44_row1_col10" class="data row1 col10" >3.996557</td>
#       <td id="T_cad44_row1_col11" class="data row1 col11" >4.018884</td>
#       <td id="T_cad44_row1_col12" class="data row1 col12" >4.023679</td>
#       <td id="T_cad44_row1_col13" class="data row1 col13" >2.958501</td>
#       <td id="T_cad44_row1_col14" class="data row1 col14" >3.985707</td>
#       <td id="T_cad44_row1_col15" class="data row1 col15" >3.985705</td>
#       <td id="T_cad44_row1_col16" class="data row1 col16" >4.014436</td>
#       <td id="T_cad44_row1_col17" class="data row1 col17" >4.012806</td>
#       <td id="T_cad44_row1_col18" class="data row1 col18" >2.876935</td>
#       <td id="T_cad44_row1_col19" class="data row1 col19" >3.988308</td>
#       <td id="T_cad44_row1_col20" class="data row1 col20" >3.988304</td>
#       <td id="T_cad44_row1_col21" clas

# %% [markdown]
# Veiem que si eliminem el DepDelay i totes les seves fonts (CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay) només l'arbre de decisió és capaç de predir ArrDelay amb un R2 de 0.68, mentres que la resta de regressors (Lineal, Ridge, Lasso i Elasticnet) es queden al voltant de 0.11, pràcticament sense associació.
